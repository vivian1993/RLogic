# %% [markdown]
# This implementation takes "/Users/leo/PycharmProjects/pytorch-tutorial/tutorials/02-intermediate/language_model" as reference

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from random import sample 
import random
from torch.nn.utils import clip_grad_norm_
import time

# %%
from data import *

# %%
def sample_anchor_rdf(rdf_data, num=1):
    return sample(rdf_data, num)


def construct_descendant(rdf_data):
    # take entity as h, map it to its r, t
    entity2desced = {}
    for rdf_ in rdf_data:
        h_, r_, t_ = parse_rdf(rdf_)
        if h_ not in entity2desced.keys():
            entity2desced[h_] = [(r_, t_)]
        else:
            entity2desced[h_].append((r_, t_))
    return entity2desced


def connected(entity2desced, head, tail):
    if head in entity2desced:
        decedents = entity2desced[head]
        for d in decedents:
            d_relation_, d_tail_ = d
            if d_tail_ == tail:
                return d_relation_
        return False
    else:
        return False

    
def construct_rule_seq(rdf_data, anchor_rdf, entity2desced, max_path_len=2, PRINT=False):    
    len2seq = {}
    """
        注意这里的 rdf 解析， 是按照(tail, relation, head)来的
        rule_seq : []
    """
    anchor_h, anchor_r, anchor_t = parse_rdf(anchor_rdf)
    # Search
    stack = [(anchor_h, anchor_r, anchor_t)]
    stack_print = ['{}-{}-{}'.format(anchor_h, anchor_r, anchor_t)]
    pre_path = anchor_h
    rule_seq, expended_node = [], []
    record = []
    while len(stack) > 0:
        cur_h, cur_r, cur_t = stack.pop(-1)
        cur_print = stack_print.pop(-1)
        deced_list = []
        
        if cur_t in entity2desced:
            deced_list = entity2desced[cur_t]  

        if len(cur_r.split('|')) < max_path_len and len(deced_list) > 0 and cur_t not in expended_node:
            for r_, t_ in deced_list:
                if t_ != cur_h and t_ != anchor_h:
                    stack.append((cur_t, cur_r+'|'+r_, t_))
                    stack_print.append(cur_print+'-{}-{}'.format(r_, t_))
        expended_node.append(cur_t)
        
        rule_head_rel = connected(entity2desced, anchor_h, cur_t)
        # 有回路
        if rule_head_rel and cur_t != anchor_t:
            rule = cur_r + '-' + rule_head_rel  
            rule_seq.append(rule)
            if (cur_h, r_, t_) not in record:
                record.append((cur_h, r_, t_))
            if PRINT:
                print('rule body:\n{}'.format(cur_print))
                print('rule head:\n{}-{}-{}'.format(anchor_h, rule_head_rel, cur_t))
                print('rule:\n{}\n'.format(rule))
        elif rule_head_rel == False and random.random() > 0.3:
            rule = cur_r + '-' + "None"
            rule_seq.append(rule)
            if (cur_h, r_, t_) not in record:
                record.append((cur_h, r_, t_))
            if PRINT:
                print('rule body:\n{}'.format(cur_print))
                print('rule head:\n{}-{}-{}'.format(anchor_h, rule_head_rel, cur_t))
                print('rule:\n{}\n'.format(rule))
                
    return rule_seq, record

# %%
# Load data from *.txt
dataset_name = ["fb15k-237", "family"]
dataset = Dataset(data_root='/Users/leo/PycharmProjects/Logic/datasets/{}/'.format(dataset_name[1]), inv=True)
rdict = dataset.get_relation_dict()
head_rdict = dataset.get_head_relation_dict()
fact_rdf = dataset.fact_rdf
entity2desced = construct_descendant(fact_rdf)
relation_num = rdict.__len__()
head_rel_num = head_rdict.__len__()

# %%
head_rdict.rel2idx
# Out:
# {'aunt': 0,
#  'brother': 1,
#  'daughter': 2,
#  'father': 3,
#  'husband': 4,
#  'mother': 5,
#  'nephew': 6,
#  'niece': 7,
#  'sister': 8,
#  'son': 9,
#  'uncle': 10,
#  'wife': 11,
#  'inv_aunt': 12,
#  'inv_brother': 13,
#  'inv_daughter': 14,
#  'inv_father': 15,
#  'inv_husband': 16,
#  'inv_mother': 17,
#  'inv_nephew': 18,
#  'inv_niece': 19,
#  'inv_sister': 20,
#  'inv_son': 21,
#  'inv_uncle': 22,
#  'inv_wife': 23,
#  'None': 24}

# %%
# Example for Constructing rule sequnce for training
#anchors_rdf = [[ '850', 'son', '828' ]]
anchors_rdf = sample_anchor_rdf(fact_rdf, num=1)

for anchor_rdf in anchors_rdf:
    anchor_h, anchor_r, anchor_t = parse_rdf(anchor_rdf)
    print("anchor:[{}-{}-{}]\n".format(anchor_h, anchor_r, anchor_t))
    rule_seq, record = construct_rule_seq(fact_rdf, anchor_rdf, entity2desced, max_path_len=4, PRINT=False)

print("rule seq:", len(rule_seq))
print("sample rdf number:", len(record))
# Out:
# anchor:[1683-inv_nephew-2654]
#
# rule seq: 147
# sample rdf number: 15

# %%
def rule2idx(rule, head_rdict):
    """
    Input a rule (string) and idx it
    """
    body, head = rule.split('-')
    body_path = body.split('|')
    # indexs include body idx seq + notation + head idx
    indexs = []
    for rel in body_path+[-1, head]:
        indexs.append(head_rdict.rel2idx[rel] if rel != -1 else -1)
    return indexs

# idx = rule2idx(rule_seq[2])
# print("rule:\t{}\nidx:\t{}".format(rule_seq[2], idx))

# %%
def enumerate_body(relation_num, body_len):
    """
    根据 relation_num, body_len 生成所有可能的 rule body
    """
    import itertools
    all_body_idx = list(list(x) for x in itertools.product(range(relation_num), repeat=body_len))
    # transfer index to relation name
    idx2rel = rdict.idx2rel
    all_body = []
    for b_idx_ in all_body_idx:
        b_ = [idx2rel[x] for x in b_idx_]
        all_body.append(b_)
    return all_body_idx, all_body

# all_body_idx, all_body = enumerate_body(relation_num, 4)

# %%
class RNN(nn.Module):
    def __init__(self, relation_num, head_rel_num, emb_size, hidden_size, num_layers=1):
        super(RNN, self).__init__()
        self.emb = nn.Embedding(relation_num, emb_size)
        self.lstm = nn.LSTM(input_size  = emb_size, 
                            hidden_size = hidden_size, 
                            num_layers  = num_layers,
                            batch_first = True)
                
        self.hid2rel = nn.Linear(hidden_size, relation_num)  
        # input body embedding predict head
        self.body2head = nn.Linear(hidden_size, head_rel_num)
        
    def forward(self, inputs, hidden):
        # inputs are one-hot tensor of relation
        inputs = self.emb(inputs)    
        out, (h,c) = self.lstm(inputs, hidden)
        out = out.reshape(out.size(0)*out.size(1), out.size(2))
        # P(B)
        pred = self.hid2rel(out)
        return pred, out, (h,c) 
    
    def predict_head(self, inputs):
        inputs = self.emb(inputs)
        batch_size = inputs.size(0)
        hidden = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
                     torch.zeros(num_layers, batch_size, hidden_size).to(device))
        out, (h,c) = self.lstm(inputs, hidden)
        body_emb = out[:, -1, :]
        # P(H, B)
        return self.body2head(body_emb)
    
    def get_relation_emb(self, rel):
        return self.emb(rel)

# %%
# data parameter
max_path_len = 3
anchor_num = 500
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Consturct training data
anchors_rdf = sample_anchor_rdf(fact_rdf, num=anchor_num)
train_rule, train_rule_idx = [],[]
len2train_rule_idx = {}
sample_number = 0
for anchor_rdf in anchors_rdf:
    rule_seq, record = construct_rule_seq(fact_rdf, anchor_rdf, entity2desced, max_path_len, PRINT=False)
    sample_number += len(record)
    # 有时候会解析出空 rule_seq
    if len(rule_seq) > 0:
        train_rule += rule_seq
        for rule in rule_seq:
            idx = torch.LongTensor(rule2idx(rule, head_rdict))
            train_rule_idx.append(idx)
            # cluster rules according to its length
            body_len = len(idx) - 2
            if body_len in len2train_rule_idx.keys():
                len2train_rule_idx[body_len] += [idx]
            else:
                len2train_rule_idx[body_len] = [idx]
rule_len_range = list(len2train_rule_idx.keys())
print("Fact set number:{} Sample number:{}".format(len(fact_rdf), sample_number))
# Out:
# Fact set number:35230 Sample number:3999

# %%
# RNN parameter
emb_size = 128
hidden_size = 256
num_layers = 1

# train parameter
n_epoch = 1000
batch_size = 50
lr = 0.005

# %%
relation_num
# Out:
# 24

# %%
# Truncated backpropagation
def detach(states):
    return [state.detach() for state in states]

# %%
# model
rnn = RNN(relation_num, head_rel_num, emb_size, hidden_size, num_layers)

# loss
loss_func_body = nn.CrossEntropyLoss()
loss_func_head = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)

# Train model
rnn.train()
start = time.clock()
for rule_len in [2, 3]:#rule_len_range:
    # initialize states        
    states = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
             torch.zeros(num_layers, batch_size, hidden_size).to(device))
    rule_ = len2train_rule_idx[rule_len]
    print("\nrule length:{} sample number:{}".format(rule_len, len(rule_)))
    loss_head, loss_body = 0, 0
    for epoch in range(n_epoch):
        rnn.zero_grad()
        sample_rule_ = sample(rule_, batch_size)
        body_ = [r_[0:-2] for r_ in sample_rule_]
        head_ = [r_[-1] for r_ in sample_rule_]
        # --------------------
        #   P(B)
        # --------------------
        inputs_b = [b_[0:-1].to(device) for b_ in body_]
        targets_b = [b_[1:].to(device) for b_ in body_]
        # stack list into Tensor
        inputs_b = torch.stack(inputs_b, 0)
        targets_b = torch.stack(targets_b, 0)
        # forward pass 
        states = detach(states)
        pred_body, out, states = rnn(inputs_b, states)
        # compute loss
        loss_body = loss_func_body(pred_body, targets_b.reshape(-1))
        
        # --------------------
        #   P(H, B)
        # --------------------
        inputs_h = body_
        targets_h = head_
        # stack list into Tensor
        inputs_h = torch.stack(inputs_h, 0)
        targets_h = torch.stack(targets_h, 0)
        # forward pass 
        pred_head = rnn.predict_head(inputs_h)
        loss_head = loss_func_head(pred_head, targets_h.reshape(-1))
        
        if epoch % (n_epoch//10) == 0:
            #print(inputs_h)
            #print(pred_head)
            #print(targets_h)
            #print(pred_head[0:5].argmax(1))
            print("### epoch:{}\tloss_head:{:.3}\tloss_body:{:.3}".format(epoch, loss_head, loss_body))
            # print(pred_body[4].argmax(), targets.reshape(-1)[4])
            
        # backward and optimize
        # clip_grad_norm_(rnn.parameters(), 0.5)
        loss = loss_body + loss_head
        loss.backward()
        
        optimizer.step()
        # targets = body_[:, (i+1):(i+1)+seq_length].to(device)
        
end = time.clock()
print("Time usage: {:.2}".format(end - start))
# Out:
# rule length:2 sample number:9721
# ### epoch:0	loss_head:3.23	loss_body:3.18
# ### epoch:100	loss_head:1.09	loss_body:2.74
# ### epoch:200	loss_head:1.09	loss_body:2.82
# ### epoch:300	loss_head:1.16	loss_body:2.8
# ### epoch:400	loss_head:1.05	loss_body:2.77
# ### epoch:500	loss_head:0.99	loss_body:2.74
# ### epoch:600	loss_head:0.921	loss_body:2.89
# ### epoch:700	loss_head:0.801	loss_body:2.86
# ### epoch:800	loss_head:1.11	loss_body:2.8
# ### epoch:900	loss_head:1.12	loss_body:2.7
#
# rule length:3 sample number:39359
# ### epoch:0	loss_head:2.47	loss_body:2.85
# ### epoch:100	loss_head:1.12	loss_body:2.58
# ### epoch:200	loss_head:1.11	loss_body:2.54
# ### epoch:300	loss_head:1.4	loss_body:2.36
# ### epoch:400	loss_head:1.14	loss_body:2.31
# ### epoch:500	loss_head:1.03	loss_body:2.49
# ### epoch:600	loss_head:1.14	loss_body:2.47
# ### epoch:700	loss_head:1.05	loss_body:2.43
# ### epoch:800	loss_head:1.1	loss_body:2.52
# ### epoch:900	loss_head:1.15	loss_body:2.32
# Time usage: 7.3e+01

# %%
# Enumerate all possible rule body and head
all_body_idx, all_body = [], []
count = 0
for body_l in [2,3]:
    tmp_i, tmp_b = enumerate_body(relation_num, body_l)
    all_body += tmp_b
    all_body_idx += tmp_i    
all_head = [x for x in head_rdict.rel2idx.keys()]

body2idx, head2idx = {}, {}
for idx, head in enumerate(all_head):
    head2idx[head] = idx
    
for idx, body in enumerate(all_body):
    body2idx["|".join(body)] = idx

# %%
# Test P(B)
body2prob = {}
rnn.eval()
with torch.no_grad():
    for idx, body_ in enumerate(all_body):
        body_idx = all_body_idx[idx]
        prob_body = 1/12.0
        states = (torch.zeros(num_layers, 1, hidden_size).to(device),
                  torch.zeros(num_layers, 1, hidden_size).to(device))
        
        for i_ in range(len(body_)-1):
            cur_ = body_idx[i_]
            next_ = body_idx[i_+1]
            inputs = torch.LongTensor([[cur_]]).to(device)
            pred_body, out, states = rnn(inputs, states)
            prob_ = torch.softmax(pred_body.squeeze(0), dim=0).tolist()
            prob_ = prob_[next_]
            prob_body = prob_body * prob_
        body2prob["|".join(body_)] = prob_body
print(body2prob)
# Out:
# {'aunt|aunt': 0.0008932494868834813, 'aunt|brother': 0.0007784272699306408, 'aunt|daughter': 0.0001207759390429904, 'aunt|father': 0.0002776282684256633, 'aunt|husband': 6.892449164297432e-05, 'aunt|mother': 0.0026071056102712946, 'aunt|nephew': 0.009906035537521044, 'aunt|niece': 0.011041725675264994, 'aunt|sister': 0.008681751166780789, 'aunt|son': 0.002878733289738496, 'aunt|uncle': 0.020058412104845047, 'aunt|wife': 1.9057931543405477e-05, 'aunt|inv_aunt': 0.007947816203037897, 'aunt|inv_brother': 2.663
091889049236e-05, 'father|inv_father': 0.0055465760330359135, 'father|inv_husband': 0.0022520643348495164, 'father|inv_mother': 2.7006395005931456e-05, 'father|inv_nephew': 0.0033778386811415353, 'father|inv_niece': 2.6522854265446462e-05, 'father|inv_sister': 2.2950485193481047e-05, 'father|inv_son': 0.015106712778409321, 'father|inv_uncle': 0.018262448410193123, 'father|inv_wife': 8.4311361812675 ...

# %%
N = 1000
S = 0
for k, v in body2prob.items():
    if v >= 0.001:
        print(k, "{:.2}".format(v))
        N -= 1
        if N == 0:
            break
# Out:
# aunt|mother 0.0026
# aunt|nephew 0.0099
# aunt|niece 0.011
# aunt|sister 0.0087
# aunt|son 0.0029
# aunt|uncle 0.02
# aunt|inv_aunt 0.0079
# aunt|inv_mother 0.0016
# aunt|inv_niece 0.0029
# aunt|inv_sister 0.01
# aunt|inv_wife 0.0026
# brother|aunt 0.0024
# brother|daughter 0.0025
# brother|nephew 0.0018
# brother|son 0.0029
# brother|uncle 0.021
# brother|wife 0.0017
# brother|inv_brother 0.0011
# brother|inv_father 0.0018
# brother|inv_nephew 0.0086
# brother|inv_son 0.018
# brother|inv_uncle 0.02
# daughter|aunt 0.0071
# daughter|nephew 0.0037
# daughter|niece 0.0047
# daughter|uncle 0.043
# daughter|inv_aunt 0.0018
# daughter|inv_niece 0.0076
# daughter|inv_sister 0.0057
# daughter|inv_wife 0.005
# father|son 0.0041
# father|uncle 0.004
# father|wife 0.026
# father|inv_father 0.0055
# father|inv_husband 0.0023
# father|inv_nephew 0.0034
# father|inv_son 0.015
# father|inv_uncle 0.018
# husband|daughter 0.0011
# husband|mother 0.0011
# husband|nephew 0.0017
# husband|niece 0.002
# husband|son 0.0075
# husband|uncle 0.016
# husband|inv_father 0.0037
# husband|inv_nephew 0.0041
# husband|inv_son 0.021
# husband|inv_uncle 0.022
# mother|daughter 0.0015
# mother|father 0.0021
# mother|husband 0.0021
# mother|mother 0.0011
# mother|nephew 0.0024
# mother|niece 0.0047
# mother|son 0.0073
# mother|uncle 0.018
# mother|inv_mother 0.0088
# mother|inv_niece 0.0021
# mother|inv_sister 0.0025
# mother|inv_wife 0.028
# nephew|aunt 0.0018
# nephew|mother 0.0011
# nephew|son 0.0011
# nephew|uncle 0.021
# nephew|wife 0.0018
# nephew|inv_father 0.0011
# nephew|inv_nephew 0.0056
# nephew|inv_son 0.015
# nephew|inv_uncle 0.031
# niece|aunt 0.0018
# niece|mother 0.0011
# niece|nephew 0.0023
# niece|niece 0.0076
# niece|uncle 0.047
# niece|inv_aunt 0.0013
# niece|inv_daughter 0.0013
# niece|inv_niece 0.0097
# niece|inv_sister 0.006
# niece|inv_wife 0.0015
# sister|aunt 0.001
# sister|daughter 0.0018
# sister|father 0.0024
# sister|mother 0.0034
# sister|nephew 0.0081
# sister|niece 0.019
# sister|sister 0.0013
# sister|son 0.0027
# sister|uncle 0.018
# sister|inv_aunt 0.006
# sister|inv_daughter 0.0013
# sister|inv_niece 0.0058
# sister|inv_sister 0.0092
# sister|inv_wife 0.0012
# son|aunt 0.0024
# son|nephew 0.0016
# son|sister 0.0011
# son|son 0.0037
# son|uncle 0.023
# son|wife 0.0036
# son|inv_father 0.0028
# son|inv_nephew 0.0089
# son|inv_son 0.011
# son|inv_uncle 0.021
# uncle|aunt 0.0024
# uncle|mother 0.0016
# uncle|nephew 0.0027
# uncle|niece 0.0028
# uncle|sister 0.0016
# uncle|son 0.0022
# uncle|uncle 0.0065
# uncle|wife 0.002
# uncle|inv_brother 0.006
# uncle|inv_father 0.0022
# uncle|inv_nephew 0.0054
# uncle|inv_son 0.012
# uncle|inv_uncle 0.035
# wife|aunt 0.0033
# wife|daughter 0.0034
# wife|father 0.002
# wife|mother 0.0013
# wife|nephew 0.0035
# wife|niece 0.0026
# wife|sister 0.0024
# wife|son 0.0094
# wife|uncle 0.0071
# wife|inv_aunt 0.0031
# wife|inv_daughter 0.0024
# wife|inv_mother 0.02
# wife|inv_niece 0.012
# wife|inv_sister 0.0025
# wife|inv_wife 0.0066
# inv_aunt|niece 0.0029
# inv_aunt|son 0.002
# inv_aunt|uncle 0.055
# inv_aunt|inv_nephew 0.001
# inv_aunt|inv_niece 0.0028
# inv_aunt|inv_sister 0.0016
# inv_aunt|inv_son 0.0052
# inv_aunt|inv_uncle 0.0081
# inv_brother|aunt 0.0013
# inv_brother|daughter 0.0014
# inv_brother|father 0.0016
# inv_brother|mother 0.0026
# inv_brother|nephew 0.0083
# inv_brother|niece 0.015
# inv_brother|sister 0.0012
# inv_brother|son 0.0012
# inv_brother|uncle 0.011
# inv_brother|wife 0.001
# inv_brother|inv_aunt 0.0014
# inv_brother|inv_nephew 0.003
# inv_brother|inv_niece 0.0022
# inv_brother|inv_sister 0.0088
# inv_brother|inv_son 0.0095
# inv_brother|inv_uncle 0.0081
# inv_daughter|nephew 0.0014
# inv_daughter|niece 0.0033
# inv_daughter|son 0.0025
# inv_daughter|uncle 0.0054
# inv_daughter|wife 0.019
# inv_daughter|inv_father 0.0017
# inv_daughter|inv_mother 0.0013
# inv_daughter|inv_nephew 0.0013
# inv_daughter|inv_son 0.0094
# inv_daughter|inv_uncle 0.01
# inv_daughter|inv_wife 0.021
# inv_father|aunt 0.0032
# inv_father|mother 0.0018
# inv_father|nephew 0.003
# inv_father|sister 0.0017
# inv_father|son 0.001
# inv_father|uncle 0.017
# inv_father|wife 0.0013
# inv_father|inv_husband 0.0011
# inv_father|inv_nephew 0.0032
# inv_father|inv_sister 0.0016
# inv_father|inv_son 0.0046
# inv_father|inv_uncle 0.038
# inv_husband|aunt 0.0011
# inv_husband|father 0.0047
# inv_husband|mother 0.0026
# inv_husband|nephew 0.007
# inv_husband|niece 0.0041
# inv_husband|son 0.0031
# inv_husband|uncle 0.034
# inv_husband|inv_aunt 0.0049
# inv_husband|inv_mother 0.0032
# inv_husband|inv_niece 0.01
# inv_husband|inv_sister 0.0022
# inv_husband|inv_wife 0.003
# inv_mother|aunt 0.002
# inv_mother|nephew 0.002
# inv_mother|niece 0.0046
# inv_mother|son 0.0043
# inv_mother|uncle 0.028
# inv_mother|wife 0.014
# inv_mother|inv_nephew 0.0031
# inv_mother|inv_niece 0.0054
# inv_mother|inv_sister 0.0073
# inv_mother|inv_uncle 0.0059
# inv_mother|inv_wife 0.0011
# inv_nephew|mother 0.0027
# inv_nephew|nephew 0.0068
# inv_nephew|niece 0.009
# inv_nephew|sister 0.0034
# inv_nephew|uncle 0.011
# inv_nephew|wife 0.0011
# inv_nephew|inv_aunt 0.014
# inv_nephew|inv_nephew 0.0023
# inv_nephew|inv_niece 0.0014
# inv_nephew|inv_sister 0.0036
# inv_nephew|inv_son 0.0042
# inv_nephew|inv_uncle 0.018
# inv_niece|mother 0.0028
# inv_niece|nephew 0.0047
# inv_niece|niece 0.0081
# inv_niece|sister 0.0016
# inv_niece|son 0.0025
# inv_niece|uncle 0.0082
# inv_niece|wife 0.0016
# inv_niece|inv_aunt 0.012
# inv_niece|inv_daughter 0.0011
# inv_niece|inv_nephew 0.0013
# inv_niece|inv_sister 0.0037
# inv_niece|inv_son 0.0063
# inv_niece|inv_uncle 0.024
# inv_niece|inv_wife 0.001
# inv_sister|aunt 0.0014
# inv_sister|mother 0.0014
# inv_sister|nephew 0.0047
# inv_sister|niece 0.0072
# inv_sister|sister 0.0014
# inv_sister|son 0.0013
# inv_sister|uncle 0.025
# inv_sister|inv_brother 0.0019
# inv_sister|inv_nephew 0.0067
# inv_sister|inv_niece 0.0024
# inv_sister|inv_sister 0.0057
# inv_sister|inv_son 0.0067
# inv_sister|inv_uncle 0.012
# inv_son|aunt 0.0016
# inv_son|daughter 0.002
# inv_son|husband 0.0011
# inv_son|mother 0.0011
# inv_son|nephew 0.0019
# inv_son|niece 0.0032
# inv_son|son 0.0049
# inv_son|uncle 0.01
# inv_son|wife 0.0028
# inv_son|inv_aunt 0.0016
# inv_son|inv_father 0.0025
# inv_son|inv_mother 0.0084
# inv_son|inv_nephew 0.0022
# inv_son|inv_niece 0.0023
# inv_son|inv_son 0.0034
# inv_son|inv_uncle 0.0043
# inv_son|inv_wife 0.026
# inv_uncle|aunt 0.0019
# inv_uncle|mother 0.0012
# inv_uncle|nephew 0.0019
# inv_uncle|niece 0.003
# inv_uncle|sister 0.0015
# inv_uncle|son 0.0013
# inv_uncle|uncle 0.036
# inv_uncle|wife 0.0012
# inv_uncle|inv_daughter 0.0011
# inv_uncle|inv_father 0.001
# inv_uncle|inv_nephew 0.0072
# inv_uncle|inv_niece 0.0035
# inv_uncle|inv_sister 0.0024
# inv_uncle|inv_son 0.0053
# inv_uncle|inv_uncle 0.012
# inv_wife|aunt 0.0013
# inv_wife|daughter 0.0035
# inv_wife|nephew 0.0023
# inv_wife|son 0.0068
# inv_wife|uncle 0.013
# inv_wife|inv_father 0.0061
# inv_wife|inv_nephew 0.0028
# inv_wife|inv_son 0.022
# inv_wife|inv_uncle 0.022
# aunt|nephew|uncle 0.0018
# aunt|nephew|inv_son 0.0015
# aunt|nephew|inv_uncle 0.0028
# aunt|niece|uncle 0.0037
# aunt|niece|inv_niece 0.0019
# aunt|sister|nephew 0.0012
# aunt|sister|niece 0.001
# aunt|sister|inv_aunt 0.0024
# aunt|uncle|nephew 0.0017
# aunt|uncle|niece 0.0018
# aunt|uncle|inv_brother 0.0027
# aunt|uncle|inv_nephew 0.0019
# aunt|uncle|inv_son 0.002
# aunt|uncle|inv_uncle 0.0062
# aunt|inv_aunt|uncle 0.002
# aunt|inv_aunt|inv_uncle 0.0011
# aunt|inv_sister|nephew 0.0011
# aunt|inv_sister|inv_aunt 0.001
# aunt|inv_sister|inv_uncle 0.0014
# brother|uncle|aunt 0.0011
# brother|uncle|nephew 0.0012
# brother|uncle|niece 0.0011
# brother|uncle|uncle 0.0012
# brother|uncle|inv_brother 0.0024
# brother|uncle|inv_nephew 0.0023
# brother|uncle|inv_son 0.002
# brother|uncle|inv_uncle 0.0052
# brother|inv_nephew|inv_aunt 0.0024
# brother|inv_nephew|inv_sister 0.0011
# brother|inv_son|daughter 0.0011
# brother|inv_son|son 0.0016
# brother|inv_son|inv_mother 0.0046
# brother|inv_son|inv_wife 0.0016
# brother|inv_uncle|aunt 0.0019
# brother|inv_uncle|uncle 0.0042
# brother|inv_uncle|inv_nephew 0.0022
# brother|inv_uncle|inv_niece 0.0014
# brother|inv_uncle|inv_uncle 0.0016
# daughter|aunt|inv_aunt 0.0011
# daughter|niece|uncle 0.0018
# daughter|uncle|aunt 0.0016
# daughter|uncle|brother 0.0016
# daughter|uncle|nephew 0.0029
# daughter|uncle|niece 0.0024
# daughter|uncle|uncle 0.0022
# daughter|uncle|inv_brother 0.0034
# daughter|uncle|inv_nephew 0.0024
# daughter|uncle|inv_son 0.004
# daughter|uncle|inv_uncle 0.019
# daughter|inv_niece|niece 0.0012
# daughter|inv_niece|inv_uncle 0.0016
# daughter|inv_sister|inv_brother 0.001
# father|wife|aunt 0.0013
# father|wife|daughter 0.0015
# father|wife|nephew 0.0011
# father|wife|niece 0.0011
# father|wife|son 0.0023
# father|wife|uncle 0.0014
# father|wife|inv_aunt 0.001
# father|wife|inv_daughter 0.0017
# father|wife|inv_mother 0.0071
# father|wife|inv_niece 0.002
# father|wife|inv_sister 0.0011
# father|wife|inv_wife 0.0017
# father|inv_son|daughter 0.0011
# father|inv_son|uncle 0.0012
# father|inv_son|inv_mother 0.0031
# father|inv_uncle|aunt 0.0017
# father|inv_uncle|uncle 0.0036
# father|inv_uncle|inv_nephew 0.003
# father|inv_uncle|inv_uncle 0.0015
# husband|son|inv_nephew 0.0022
# husband|uncle|nephew 0.0012
# husband|uncle|inv_brother 0.0031
# husband|uncle|inv_nephew 0.0018
# husband|uncle|inv_son 0.0015
# husband|uncle|inv_uncle 0.0032
# husband|inv_son|daughter 0.0013
# husband|inv_son|son 0.0017
# husband|inv_son|uncle 0.0011
# husband|inv_son|inv_mother 0.0051
# husband|inv_son|inv_niece 0.0011
# husband|inv_son|inv_wife 0.0012
# husband|inv_uncle|aunt 0.0021
# husband|inv_uncle|niece 0.0013
# husband|inv_uncle|uncle 0.003
# husband|inv_uncle|inv_nephew 0.0025
# husband|inv_uncle|inv_niece 0.0029
# husband|inv_uncle|inv_uncle 0.0011
# mother|niece|uncle 0.002
# mother|son|inv_nephew 0.0012
# mother|uncle|nephew 0.0012
# mother|uncle|inv_brother 0.0032
# mother|uncle|inv_nephew 0.0029
# mother|uncle|inv_son 0.0017
# mother|uncle|inv_uncle 0.0043
# mother|inv_mother|niece 0.0011
# mother|inv_mother|uncle 0.0014
# mother|inv_wife|aunt 0.0014
# mother|inv_wife|daughter 0.0033
# mother|inv_wife|nephew 0.0014
# mother|inv_wife|sister 0.0011
# mother|inv_wife|son 0.002
# mother|inv_wife|uncle 0.0013
# mother|inv_wife|inv_brother 0.005
# mother|inv_wife|inv_father 0.0027
# mother|inv_wife|inv_nephew 0.0026
# mother|inv_wife|inv_son 0.0019
# mother|inv_wife|inv_uncle 0.0025
# nephew|uncle|aunt 0.0012
# nephew|uncle|nephew 0.0014
# nephew|uncle|niece 0.0011
# nephew|uncle|uncle 0.0011
# nephew|uncle|inv_brother 0.002
# nephew|uncle|inv_nephew 0.0013
# nephew|uncle|inv_son 0.002
# nephew|uncle|inv_uncle 0.0072
# nephew|inv_son|daughter 0.001
# nephew|inv_son|son 0.0016
# nephew|inv_son|uncle 0.002
# nephew|inv_son|inv_mother 0.002
# nephew|inv_son|inv_wife 0.0011
# nephew|inv_uncle|aunt 0.0016
# nephew|inv_uncle|nephew 0.0013
# nephew|inv_uncle|niece 0.0012
# nephew|inv_uncle|uncle 0.01
# nephew|inv_uncle|inv_nephew 0.0023
# nephew|inv_uncle|inv_niece 0.002
# nephew|inv_uncle|inv_son 0.0021
# nephew|inv_uncle|inv_uncle 0.003
# niece|niece|uncle 0.0031
# niece|uncle|aunt 0.0019
# niece|uncle|brother 0.0019
# niece|uncle|nephew 0.0042
# niece|uncle|niece 0.004
# niece|uncle|sister 0.0013
# niece|uncle|uncle 0.0025
# niece|uncle|inv_brother 0.004
# niece|uncle|inv_father 0.001
# niece|uncle|inv_nephew 0.0024
# niece|uncle|inv_son 0.0037
# niece|uncle|inv_uncle 0.016
# niece|inv_niece|niece 0.0011
# niece|inv_niece|inv_uncle 0.0015
# niece|inv_sister|inv_brother 0.0014
# sister|mother|inv_mother 0.0015
# sister|nephew|uncle 0.0014
# sister|nephew|inv_nephew 0.0015
# sister|nephew|inv_uncle 0.0013
# sister|niece|aunt 0.0015
# sister|niece|niece 0.0015
# sister|niece|uncle 0.005
# sister|niece|inv_aunt 0.001
# sister|niece|inv_niece 0.0034
# sister|niece|inv_sister 0.0025
# sister|uncle|nephew 0.001
# sister|uncle|niece 0.0014
# sister|uncle|sister 0.001
# sister|uncle|inv_brother 0.0031
# sister|uncle|inv_nephew 0.0016
# sister|uncle|inv_uncle 0.0061
# sister|inv_aunt|uncle 0.0014
# sister|inv_niece|inv_aunt 0.0021
# sister|inv_sister|uncle 0.0013
# sister|inv_sister|inv_uncle 0.0013
# son|uncle|aunt 0.0011
# son|uncle|nephew 0.0013
# son|uncle|niece 0.0013
# son|uncle|uncle 0.0011
# son|uncle|inv_brother 0.0041
# son|uncle|inv_nephew 0.0018
# son|uncle|inv_son 0.0025
# son|uncle|inv_uncle 0.0059
# son|wife|inv_mother 0.0011
# son|inv_nephew|uncle 0.0011
# son|inv_nephew|inv_uncle 0.001
# son|inv_son|son 0.001
# son|inv_son|uncle 0.0011
# son|inv_son|inv_mother 0.0019
# son|inv_uncle|aunt 0.0016
# son|inv_uncle|nephew 0.0013
# son|inv_uncle|uncle 0.0053
# son|inv_uncle|inv_nephew 0.0026
# son|inv_uncle|inv_niece 0.0014
# son|inv_uncle|inv_uncle 0.0015
# uncle|uncle|inv_uncle 0.0019
# uncle|inv_nephew|inv_aunt 0.001
# uncle|inv_son|uncle 0.0015
# uncle|inv_son|inv_mother 0.0017
# uncle|inv_son|inv_wife 0.001
# uncle|inv_uncle|aunt 0.0032
# uncle|inv_uncle|nephew 0.0028
# uncle|inv_uncle|niece 0.0015
# uncle|inv_uncle|sister 0.0011
# uncle|inv_uncle|uncle 0.0074
# uncle|inv_uncle|inv_brother 0.0011
# uncle|inv_uncle|inv_nephew 0.0026
# uncle|inv_uncle|inv_niece 0.0019
# uncle|inv_uncle|inv_son 0.0017
# uncle|inv_uncle|inv_uncle 0.0037
# wife|daughter|uncle 0.0019
# wife|nephew|inv_uncle 0.0011
# wife|niece|uncle 0.0012
# wife|son|uncle 0.0011
# wife|son|inv_nephew 0.0018
# wife|son|inv_uncle 0.0015
# wife|uncle|inv_son 0.0011
# wife|uncle|inv_uncle 0.0025
# wife|inv_aunt|uncle 0.0016
# wife|inv_mother|nephew 0.001
# wife|inv_mother|niece 0.0012
# wife|inv_mother|uncle 0.0041
# wife|inv_mother|wife 0.0015
# wife|inv_mother|inv_nephew 0.0013
# wife|inv_mother|inv_niece 0.0028
# wife|inv_mother|inv_sister 0.0016
# wife|inv_mother|inv_uncle 0.0016
# wife|inv_niece|niece 0.0014
# wife|inv_niece|uncle 0.0011
# wife|inv_niece|inv_son 0.0018
# wife|inv_niece|inv_uncle 0.003
# wife|inv_wife|inv_uncle 0.0014
# inv_aunt|niece|uncle 0.0012
# inv_aunt|uncle|aunt 0.0012
# inv_aunt|uncle|brother 0.0015
# inv_aunt|uncle|nephew 0.0049
# inv_aunt|uncle|niece 0.0042
# inv_aunt|uncle|sister 0.0014
# inv_aunt|uncle|uncle 0.0036
# inv_aunt|uncle|inv_brother 0.0038
# inv_aunt|uncle|inv_nephew 0.0026
# inv_aunt|uncle|inv_son 0.0064
# inv_aunt|uncle|inv_uncle 0.021
# inv_aunt|inv_uncle|uncle 0.0029
# inv_brother|mother|inv_mother 0.0012
# inv_brother|nephew|uncle 0.0018
# inv_brother|nephew|inv_nephew 0.0011
# inv_brother|nephew|inv_uncle 0.0014
# inv_brother|niece|niece 0.0013
# inv_brother|niece|uncle 0.0047
# inv_brother|niece|inv_niece 0.0019
# inv_brother|niece|inv_sister 0.0022
# inv_brother|uncle|inv_brother 0.0012
# inv_brother|uncle|inv_son 0.0011
# inv_brother|uncle|inv_uncle 0.0046
# inv_brother|inv_sister|nephew 0.001
# inv_brother|inv_sister|niece 0.0017
# inv_brother|inv_sister|inv_uncle 0.0013
# inv_brother|inv_son|inv_mother 0.0016
# inv_brother|inv_uncle|uncle 0.0018
# inv_daughter|niece|uncle 0.0016
# inv_daughter|uncle|inv_uncle 0.0015
# inv_daughter|wife|son 0.001
# inv_daughter|wife|inv_mother 0.01
# inv_daughter|wife|inv_wife 0.0019
# inv_daughter|inv_son|inv_mother 0.0016
# inv_daughter|inv_uncle|uncle 0.003
# inv_daughter|inv_uncle|inv_nephew 0.0014
# inv_daughter|inv_wife|daughter 0.0022
# inv_daughter|inv_wife|son 0.0018
# inv_daughter|inv_wife|uncle 0.0021
# inv_daughter|inv_wife|inv_father 0.0033
# inv_daughter|inv_wife|inv_nephew 0.002
# inv_daughter|inv_wife|inv_son 0.003
# inv_daughter|inv_wife|inv_uncle 0.0029
# inv_father|uncle|uncle 0.0013
# inv_father|uncle|inv_nephew 0.001
# inv_father|uncle|inv_son 0.0024
# inv_father|uncle|inv_uncle 0.0069
# inv_father|inv_uncle|aunt 0.0029
# inv_father|inv_uncle|nephew 0.0019
# inv_father|inv_uncle|niece 0.0013
# inv_father|inv_uncle|uncle 0.0093
# inv_father|inv_uncle|inv_nephew 0.0053
# inv_father|inv_uncle|inv_niece 0.0033
# inv_father|inv_uncle|inv_son 0.0017
# inv_father|inv_uncle|inv_uncle 0.0027
# inv_husband|nephew|uncle 0.0012
# inv_husband|nephew|inv_nephew 0.0013
# inv_husband|nephew|inv_uncle 0.0015
# inv_husband|niece|uncle 0.001
# inv_husband|niece|inv_niece 0.0011
# inv_husband|uncle|aunt 0.0011
# inv_husband|uncle|brother 0.0012
# inv_husband|uncle|nephew 0.003
# inv_husband|uncle|niece 0.0023
# inv_husband|uncle|sister 0.0012
# inv_husband|uncle|uncle 0.0012
# inv_husband|uncle|inv_brother 0.0051
# inv_husband|uncle|inv_nephew 0.0029
# inv_husband|uncle|inv_son 0.0028
# inv_husband|uncle|inv_uncle 0.0087
# inv_husband|inv_aunt|uncle 0.0021
# inv_husband|inv_niece|nephew 0.001
# inv_husband|inv_niece|niece 0.0011
# inv_husband|inv_niece|inv_uncle 0.0018
# inv_mother|niece|uncle 0.0015
# inv_mother|uncle|brother 0.0011
# inv_mother|uncle|nephew 0.002
# inv_mother|uncle|niece 0.0019
# inv_mother|uncle|uncle 0.0019
# inv_mother|uncle|inv_brother 0.002
# inv_mother|uncle|inv_nephew 0.0019
# inv_mother|uncle|inv_son 0.003
# inv_mother|uncle|inv_uncle 0.01
# inv_mother|wife|inv_aunt 0.0016
# inv_mother|wife|inv_daughter 0.0016
# inv_mother|wife|inv_mother 0.0025
# inv_mother|wife|inv_niece 0.0013
# inv_mother|inv_sister|inv_brother 0.0013
# inv_mother|inv_uncle|uncle 0.0011
# inv_nephew|nephew|uncle 0.0012
# inv_nephew|nephew|inv_uncle 0.0023
# inv_nephew|niece|uncle 0.0026
# inv_nephew|niece|inv_niece 0.0018
# inv_nephew|sister|inv_aunt 0.0011
# inv_nephew|uncle|inv_brother 0.0013
# inv_nephew|uncle|inv_nephew 0.001
# inv_nephew|uncle|inv_uncle 0.0036
# inv_nephew|inv_aunt|aunt 0.0011
# inv_nephew|inv_aunt|uncle 0.0029
# inv_nephew|inv_aunt|inv_niece 0.0015
# inv_nephew|inv_aunt|inv_uncle 0.0018
# inv_nephew|inv_uncle|aunt 0.0018
# inv_nephew|inv_uncle|nephew 0.0011
# inv_nephew|inv_uncle|niece 0.0011
# inv_nephew|inv_uncle|uncle 0.003
# inv_nephew|inv_uncle|inv_nephew 0.0012
# inv_nephew|inv_uncle|inv_niece 0.0011
# inv_nephew|inv_uncle|inv_uncle 0.0025
# inv_niece|nephew|inv_uncle 0.0011
# inv_niece|niece|uncle 0.0024
# inv_niece|niece|inv_niece 0.0015
# inv_niece|uncle|inv_brother 0.001
# inv_niece|uncle|inv_uncle 0.0023
# inv_niece|inv_aunt|uncle 0.0028
# inv_niece|inv_aunt|inv_niece 0.0014
# inv_niece|inv_aunt|inv_uncle 0.001
# inv_niece|inv_son|inv_mother 0.0012
# inv_niece|inv_uncle|aunt 0.0021
# inv_niece|inv_uncle|nephew 0.0025
# inv_niece|inv_uncle|sister 0.0013
# inv_niece|inv_uncle|uncle 0.0051
# inv_niece|inv_uncle|inv_nephew 0.0017
# inv_niece|inv_uncle|inv_niece 0.0011
# inv_niece|inv_uncle|inv_son 0.0012
# inv_niece|inv_uncle|inv_uncle 0.0034
# inv_sister|nephew|inv_uncle 0.001
# inv_sister|niece|uncle 0.0025
# inv_sister|uncle|nephew 0.0012
# inv_sister|uncle|niece 0.0015
# inv_sister|uncle|uncle 0.0017
# inv_sister|uncle|inv_brother 0.0032
# inv_sister|uncle|inv_nephew 0.0026
# inv_sister|uncle|inv_son 0.0021
# inv_sister|uncle|inv_uncle 0.0084
# inv_sister|inv_nephew|inv_aunt 0.0014
# inv_sister|inv_sister|uncle 0.0011
# inv_sister|inv_son|inv_mother 0.0012
# inv_sister|inv_son|inv_wife 0.0011
# inv_sister|inv_uncle|uncle 0.0034
# inv_sister|inv_uncle|inv_nephew 0.001
# inv_sister|inv_uncle|inv_uncle 0.0012
# inv_son|niece|uncle 0.0014
# inv_son|uncle|inv_brother 0.001
# inv_son|uncle|inv_nephew 0.0016
# inv_son|uncle|inv_son 0.0014
# inv_son|uncle|inv_uncle 0.0025
# inv_son|inv_mother|niece 0.0014
# inv_son|inv_mother|uncle 0.0012
# inv_son|inv_wife|aunt 0.0013
# inv_son|inv_wife|daughter 0.0018
# inv_son|inv_wife|nephew 0.0011
# inv_son|inv_wife|son 0.0021
# inv_son|inv_wife|uncle 0.0014
# inv_son|inv_wife|inv_brother 0.0033
# inv_son|inv_wife|inv_father 0.0038
# inv_son|inv_wife|inv_nephew 0.0019
# inv_son|inv_wife|inv_son 0.003
# inv_son|inv_wife|inv_uncle 0.0028
# inv_uncle|niece|uncle 0.0012
# inv_uncle|uncle|aunt 0.0013
# inv_uncle|uncle|brother 0.0012
# inv_uncle|uncle|nephew 0.0026
# inv_uncle|uncle|niece 0.0023
# inv_uncle|uncle|uncle 0.0022
# inv_uncle|uncle|inv_brother 0.0033
# inv_uncle|uncle|inv_nephew 0.0027
# inv_uncle|uncle|inv_son 0.0037
# inv_uncle|uncle|inv_uncle 0.012
# inv_uncle|inv_uncle|uncle 0.0027
# inv_uncle|inv_uncle|inv_nephew 0.0011
# inv_uncle|inv_uncle|inv_uncle 0.0012
# inv_wife|daughter|uncle 0.0017
# inv_wife|son|uncle 0.0011
# inv_wife|son|inv_nephew 0.0016
# inv_wife|uncle|inv_brother 0.0023
# inv_wife|uncle|inv_nephew 0.0014
# inv_wife|uncle|inv_son 0.0014
# inv_wife|uncle|inv_uncle 0.0027
# inv_wife|inv_father|uncle 0.0011
# inv_wife|inv_son|daughter 0.0015
# inv_wife|inv_son|son 0.0019
# inv_wife|inv_son|uncle 0.0012
# inv_wife|inv_son|inv_father 0.0012
# inv_wife|inv_son|inv_mother 0.0035
# inv_wife|inv_son|inv_nephew 0.0012
# inv_wife|inv_son|inv_niece 0.0012
# inv_wife|inv_son|inv_son 0.0012
# inv_wife|inv_uncle|aunt 0.0016
# inv_wife|inv_uncle|uncle 0.004
# inv_wife|inv_uncle|inv_nephew 0.0035
# inv_wife|inv_uncle|inv_niece 0.0019
# inv_wife|inv_uncle|inv_uncle 0.0016

# %%
# Test P(H|B)
f =  open('./ours_rule_{}.txt', 'w')
body2head = {}
rnn.eval()
with torch.no_grad():    
    # Enumerate all possible rule body
    for body_l in [2, 3, 4, 5, 6]:#range(2, max_path_len+1):
        N = 0
        all_body_idx, all_body = enumerate_body(relation_num, body_l)
        for idx, body_idx in enumerate(all_body_idx):
            body_ = all_body[idx]
            inputs = torch.LongTensor([body_idx]).to(device)
            pred_head = rnn.predict_head(inputs)
            prob_ = torch.softmax(pred_head.squeeze(0), dim=0)
            max_head_ = head_rdict.idx2rel[prob_.argmax().item()]
            if max_head_ != "None":
                print(max_head_, "← ", " , ".join(body_),   ': {:.2}'.format(prob_.max()) )
            
            for i, p in enumerate(prob_.tolist()):
                if p < 0.1:
                    continue
                head_rel = head_rdict.idx2rel[i]
                if head_rel != 'None' and 'inv' not in head_rel:
                    w_r = "{:.3f} ({:.3f})\t{} <-- ".format(p, p, head_rel)
                    w_r += ", ".join(body_)
                    f.write(w_r+"\n")
            
            head_prob_list = []
            for i, p in enumerate(prob_.tolist()):
                head_ = head_rdict.idx2rel[i]
                head_prob_list.append((head_, p))
            body2head["|".join(body_)] = head_prob_list
            
f.close()
# Out:
# inv_nephew ←  aunt , brother : 0.4
# aunt ←  aunt , sister : 0.57
# aunt ←  brother , aunt : 0.77
# brother ←  brother , brother : 0.58
# niece ←  brother , daughter : 0.64
# father ←  brother , father : 0.42
# mother ←  brother , mother : 0.49
# nephew ←  brother , nephew : 0.41
# niece ←  brother , niece : 0.63
# sister ←  brother , sister : 0.51
# nephew ←  brother , son : 0.57
# inv_nephew ←  brother , uncle : 0.42
# niece ←  brother , inv_aunt : 0.39
# sister ←  brother , inv_brother : 0.4
# inv_aunt ←  brother , inv_father : 0.28
# niece ←  brother , inv_mother : 0.38
# aunt ←  brother , inv_nephew : 0.39
# aunt ←  brother , inv_niece : 0.32
# brother ←  brother , inv_sister : 0.31
# inv_aunt ←  brother , inv_uncle : 0.37
# inv_sister ←  daughter , aunt : 0.33
# inv_father ←  daughter , brother : 0.39
# inv_husband ←  daughter , mother : 0.42
# daughter ←  daughter , sister : 0.5
# brother ←  daughter , uncle : 0.58
# inv_mother ←  daughter , inv_brother : 0.29
# inv_husband ←  daughter , inv_daughter : 0.49
# brother ←  daughter , inv_nephew : 0.31
# inv_father ←  daughter , inv_sister : 0.4
# inv_sister ←  father , daughter : 0.36
# brother ←  father , son : 0.44
# brother ←  father , inv_father : 0.25
# inv_mother ←  husband , inv_father : 0.31
# inv_nephew ←  mother , brother : 0.48
# inv_brother ←  mother , daughter : 0.43
# aunt ←  mother , sister : 0.52
# brother ←  mother , son : 0.37
# inv_nephew ←  mother , inv_brother : 0.41
# inv_sister ←  mother , inv_father : 0.22
# mother ←  mother , inv_husband : 0.61
# inv_brother ←  mother , inv_mother : 0.22
# aunt ←  mother , inv_sister : 0.31
# brother ←  nephew , father : 0.5
# niece ←  nephew , sister : 0.48
# brother ←  nephew , uncle : 0.42
# nephew ←  nephew , inv_brother : 0.31
# inv_sister ←  nephew , inv_nephew : 0.26
# nephew ←  nephew , inv_sister : 0.34
# inv_sister ←  niece , aunt : 0.35
# brother ←  niece , father : 0.42
# sister ←  niece , inv_nephew : 0.24
# sister ←  niece , inv_niece : 0.25
# nephew ←  niece , inv_sister : 0.32
# aunt ←  sister , aunt : 0.81
# brother ←  sister , brother : 0.67
# niece ←  sister , daughter : 0.5
# mother ←  sister , mother : 0.67
# nephew ←  sister , nephew : 0.48
# niece ←  sister , niece : 0.51
# sister ←  sister , sister : 0.49
# nephew ←  sister , son : 0.52
# inv_nephew ←  sister , uncle : 0.49
# niece ←  sister , inv_aunt : 0.47
# inv_brother ←  sister , inv_brother : 0.34
# mother ←  sister , inv_daughter : 0.44
# niece ←  sister , inv_mother : 0.37
# aunt ←  sister , inv_nephew : 0.29
# inv_nephew ←  sister , inv_niece : 0.39
# brother ←  sister , inv_sister : 0.37
# niece ←  sister , inv_uncle : 0.25
# daughter ←  son , sister : 0.43
# inv_mother ←  son , inv_brother : 0.26
# aunt ←  uncle , sister : 0.42
# nephew ←  wife , son : 0.42
# inv_sister ←  inv_aunt , aunt : 0.64
# inv_aunt ←  inv_aunt , brother : 0.42
# brother ←  inv_aunt , father : 0.49
# inv_aunt ←  inv_aunt , sister : 0.54
# inv_sister ←  inv_aunt , uncle : 0.43
# inv_aunt ←  inv_aunt , inv_brother : 0.71
# inv_sister ←  inv_aunt , inv_daughter : 0.32
# inv_sister ←  inv_aunt , inv_nephew : 0.46
# inv_sister ←  inv_aunt , inv_niece : 0.44
# inv_aunt ←  inv_aunt , inv_sister : 0.68
# inv_sister ←  inv_aunt , inv_son : 0.39
# aunt ←  inv_brother , aunt : 0.82
# inv_brother ←  inv_brother , brother : 0.51
# niece ←  inv_brother , daughter : 0.54
# father ←  inv_brother , father : 0.77
# mother ←  inv_brother , mother : 0.94
# nephew ←  inv_brother , nephew : 0.58
# niece ←  inv_brother , niece : 0.63
# inv_brother ←  inv_brother , sister : 0.73
# nephew ←  inv_brother , son : 0.65
# inv_nephew ←  inv_brother , uncle : 0.86
# inv_uncle ←  inv_brother , inv_aunt : 0.42
# inv_brother ←  inv_brother , inv_brother : 0.65
# mother ←  inv_brother , inv_daughter : 0.5
# inv_uncle ←  inv_brother , inv_father : 0.65
# nephew ←  inv_brother , inv_mother : 0.44
# inv_nephew ←  inv_brother , inv_nephew : 0.46
# inv_nephew ←  inv_brother , inv_niece : 0.72
# inv_brother ←  inv_brother , inv_sister : 0.69
# mother ←  inv_brother , inv_son : 0.43
# niece ←  inv_brother , inv_uncle : 0.36
# inv_sister ←  inv_daughter , daughter : 0.64
# inv_sister ←  inv_daughter , son : 0.77
# inv_sister ←  inv_daughter , inv_father : 0.7
# inv_brother ←  inv_father , aunt : 0.38
# inv_father ←  inv_father , brother : 0.52
# daughter ←  inv_father , sister : 0.95
# inv_brother ←  inv_father , uncle : 0.73
# daughter ←  inv_father , inv_brother : 0.55
# inv_brother ←  inv_father , inv_nephew : 0.31
# inv_brother ←  inv_father , inv_niece : 0.43
# daughter ←  inv_father , inv_sister : 0.56
# inv_mother ←  inv_mother , brother : 0.63
# daughter ←  inv_mother , sister : 0.37
# inv_mother ←  inv_mother , inv_brother : 0.58
# husband ←  inv_mother , inv_daughter : 0.55
# inv_mother ←  inv_mother , inv_sister : 0.49
# inv_nephew ←  inv_nephew , brother : 0.58
# aunt ←  inv_nephew , sister : 0.43
# inv_nephew ←  inv_nephew , inv_brother : 0.34
# inv_nephew ←  inv_nephew , inv_sister : 0.42
# inv_niece ←  inv_niece , brother : 0.48
# inv_niece ←  inv_niece , inv_sister : 0.45
# aunt ←  inv_sister , aunt : 0.82
# brother ←  inv_sister , brother : 0.67
# inv_aunt ←  inv_sister , daughter : 0.46
# inv_daughter ←  inv_sister , mother : 0.61
# inv_aunt ←  inv_sister , nephew : 0.64
# inv_aunt ←  inv_sister , niece : 0.6
# inv_sister ←  inv_sister , sister : 0.47
# nephew ←  inv_sister , son : 0.54
# inv_niece ←  inv_sister , uncle : 0.75
# inv_aunt ←  inv_sister , inv_aunt : 0.41
# brother ←  inv_sister , inv_brother : 0.4
# inv_aunt ←  inv_sister , inv_father : 0.6
# inv_niece ←  inv_sister , inv_nephew : 0.6
# inv_niece ←  inv_sister , inv_niece : 0.46
# brother ←  inv_sister , inv_sister : 0.48
# inv_daughter ←  inv_sister , inv_son : 0.52
# inv_aunt ←  inv_sister , inv_uncle : 0.62
# inv_nephew ←  inv_son , brother : 0.69
# inv_brother ←  inv_son , daughter : 0.79
# aunt ←  inv_son , sister : 0.58
# inv_brother ←  inv_son , son : 0.68
# mother ←  inv_son , wife : 0.56
# inv_nephew ←  inv_son , inv_brother : 0.56
# inv_brother ←  inv_son , inv_father : 0.61
# mother ←  inv_son , inv_husband : 0.72
# inv_brother ←  inv_son , inv_mother : 0.46
# nephew ←  inv_uncle , brother : 0.49
# niece ←  inv_uncle , sister : 0.63
# niece ←  inv_uncle , inv_brother : 0.28
# nephew ←  inv_uncle , inv_sister : 0.36
# aunt ←  aunt , daughter , aunt : 0.49
# aunt ←  aunt , father , daughter : 0.49
# inv_niece ←  aunt , father , son : 0.44
# aunt ←  aunt , father , inv_father : 0.28
# aunt ←  aunt , mother , daughter : 0.62
# inv_niece ←  aunt , mother , son : 0.59
# inv_niece ←  aunt , mother , inv_mother : 0.39
# aunt ←  aunt , nephew , aunt : 0.51
# brother ←  aunt , nephew , brother : 0.45
# inv_niece ←  aunt , nephew , father : 0.31
# inv_niece ←  aunt , nephew , uncle : 0.42
# inv_niece ←  aunt , nephew , inv_daughter : 0.29
# inv_niece ←  aunt , nephew , inv_nephew : 0.37
# inv_sister ←  aunt , nephew , inv_sister : 0.25
# aunt ←  aunt , niece , aunt : 0.56
# mother ←  aunt , niece , mother : 0.28
# inv_nephew ←  aunt , niece , uncle : 0.26
# inv_niece ←  aunt , niece , inv_nephew : 0.23
# inv_nephew ←  aunt , sister , brother : 0.35
# sister ←  aunt , sister , daughter : 0.48
# aunt ←  aunt , sister , sister : 0.64
# inv_nephew ←  aunt , sister , inv_brother : 0.29
# mother ←  aunt , sister , inv_husband : 0.4
# aunt ←  aunt , sister , inv_sister : 0.43
# aunt ←  aunt , son , aunt : 0.39
# inv_niece ←  aunt , son , uncle : 0.35
# inv_niece ←  aunt , son , inv_nephew : 0.32
# aunt ←  aunt , inv_aunt , aunt : 0.58
# brother ←  aunt , inv_aunt , brother : 0.49
# uncle ←  aunt , inv_aunt , father : 0.23
# mother ←  aunt , inv_aunt , mother : 0.3
# uncle ←  aunt , inv_aunt , uncle : 0.29
# inv_niece ←  aunt , inv_aunt , inv_nephew : 0.27
# brother ←  aunt , inv_aunt , inv_sister : 0.25
# inv_nephew ←  aunt , inv_brother , brother : 0.33
# aunt ←  aunt , inv_brother , sister : 0.54
# aunt ←  aunt , inv_brother , inv_brother : 0.28
# aunt ←  aunt , inv_brother , inv_sister : 0.31
# aunt ←  aunt , inv_daughter , daughter : 0.48
# inv_niece ←  aunt , inv_daughter , son : 0.38
# aunt ←  aunt , inv_father , aunt : 0.61
# inv_niece ←  aunt , inv_father , inv_nephew : 0.33
# inv_nephew ←  aunt , inv_father , inv_niece : 0.24
# inv_niece ←  aunt , inv_mother , aunt : 0.37
# inv_niece ←  aunt , inv_mother , uncle : 0.39
# inv_niece ←  aunt , inv_mother , inv_nephew : 0.4
# inv_niece ←  aunt , inv_mother , inv_niece : 0.41
# inv_nephew ←  aunt , inv_sister , brother : 0.35
# aunt ←  aunt , inv_sister , sister : 0.64
# inv_nephew ←  aunt , inv_sister , inv_brother : 0.32
# aunt ←  aunt , inv_sister , inv_sister : 0.38
# aunt ←  aunt , inv_son , daughter : 0.53
# inv_niece ←  aunt , inv_son , son : 0.36
# aunt ←  aunt , inv_son , inv_father : 0.31
# aunt ←  aunt , inv_uncle , aunt : 0.57
# inv_niece ←  aunt , inv_uncle , uncle : 0.35
# inv_niece ←  aunt , inv_uncle , inv_nephew : 0.3
# inv_niece ←  brother , aunt , brother : 0.41
# aunt ←  brother , aunt , sister : 0.7
# aunt ←  brother , aunt , inv_brother : 0.35
# aunt ←  brother , aunt , inv_sister : 0.41
# aunt ←  brother , brother , aunt : 0.84
# brother ←  brother , brother , brother : 0.6
# niece ←  brother , brother , daughter : 0.64
# inv_daughter ←  brother , brother , mother : 0.41
# nephew ←  brother , brother , nephew : 0.36
# niece ←  brother , brother , niece : 0.61
# sister ←  brother , brother , sister : 0.47
# nephew ←  brother , brother , son : 0.51
# inv_nephew ←  brother , brother , uncle : 0.39
# niece ←  brother , brother , inv_aunt : 0.38
# sister ←  brother , brother , inv_brother : 0.34
# inv_aunt ←  brother , brother , inv_father : 0.34
# inv_aunt ←  brother , brother , inv_mother : 0.35
# aunt ←  brother , brother , inv_nephew : 0.4
# aunt ←  brother , brother , inv_niece : 0.3
# sister ←  brother , brother , inv_sister : 0.27
# inv_aunt ←  brother , brother , inv_uncle : 0.36
# sister ←  brother , daughter , aunt : 0.4
# nephew ←  brother , daughter , brother : 0.47
# inv_brother ←  brother , daughter , mother : 0.35
# niece ←  brother , daughter , sister : 0.68
# brother ←  brother , daughter , uncle : 0.5
# inv_aunt ←  brother , daughter , inv_brother : 0.37
# sister ←  brother , daughter , inv_nephew : 0.28
# sister ←  brother , daughter , inv_niece : 0.39
# inv_aunt ←  brother , daughter , inv_sister : 0.31
# inv_nephew ←  brother , father , brother : 0.34
# inv_sister ←  brother , father , daughter : 0.43
# aunt ←  brother , father , sister : 0.51
# brother ←  brother , father , son : 0.46
# inv_niece ←  brother , father , inv_brother : 0.25
# inv_brother ←  brother , father , inv_father : 0.3
# mother ←  brother , father , inv_husband : 0.79
# aunt ←  brother , father , inv_sister : 0.32
# aunt ←  brother , husband , aunt : 0.53
# niece ←  brother , husband , daughter : 0.58
# nephew ←  brother , husband , son : 0.41
# inv_aunt ←  brother , husband , inv_father : 0.35
# inv_niece ←  brother , mother , brother : 0.37
# sister ←  brother , mother , daughter : 0.44
# aunt ←  brother , mother , sister : 0.68
# brother ←  brother , mother , son : 0.42
# mother ←  brother , mother , wife : 0.59
# aunt ←  brother , mother , inv_brother : 0.39
# inv_sister ←  brother , mother , inv_father : 0.3
# mother ←  brother , mother , inv_husband : 0.87
# inv_brother ←  brother , mother , inv_mother : 0.34
# inv_niece ←  brother , mother , inv_sister : 0.55
# sister ←  brother , nephew , aunt : 0.48
# nephew ←  brother , nephew , brother : 0.59
# brother ←  brother , nephew , father : 0.33
# niece ←  brother , nephew , sister : 0.72
# brother ←  brother , nephew , uncle : 0.5
# nephew ←  brother , nephew , inv_brother : 0.57
# sister ←  brother , nephew , inv_nephew : 0.37
# sister ←  brother , nephew , inv_niece : 0.24
# nephew ←  brother , nephew , inv_sister : 0.44
# sister ←  brother , niece , aunt : 0.43
# nephew ←  brother , niece , brother : 0.51
# niece ←  brother , niece , sister : 0.56
# brother ←  brother , niece , uncle : 0.45
# nephew ←  brother , niece , inv_brother : 0.41
# sister ←  brother , niece , inv_nephew : 0.31
# sister ←  brother , niece , inv_niece : 0.35
# nephew ←  brother , niece , inv_sister : 0.49
# aunt ←  brother , sister , aunt : 0.87
# brother ←  brother , sister , brother : 0.71
# niece ←  brother , sister , daughter : 0.68
# mother ←  brother , sister , mother : 0.65
# nephew ←  brother , sister , nephew : 0.54
# niece ←  brother , sister , niece : 0.61
# sister ←  brother , sister , sister : 0.52
# nephew ←  brother , sister , son : 0.68
# inv_nephew ←  brother , sister , uncle : 0.41
# niece ←  brother , sister , inv_aunt : 0.5
# sister ←  brother , sister , inv_brother : 0.35
# mother ←  brother , sister , inv_daughter : 0.38
# nephew ←  brother , sister , inv_father : 0.37
# niece ←  brother , sister , inv_mother : 0.4
# aunt ←  brother , sister , inv_nephew : 0.37
# inv_nephew ←  brother , sister , inv_niece : 0.27
# brother ←  brother , sister , inv_sister : 0.37
# niece ←  brother , sister , inv_uncle : 0.29
# sister ←  brother , son , aunt : 0.39
# nephew ←  brother , son , brother : 0.47
# niece ←  brother , son , sister : 0.63
# brother ←  brother , son , uncle : 0.41
# nephew ←  brother , son , inv_brother : 0.33
# sister ←  brother , son , inv_nephew : 0.32
# inv_aunt ←  brother , son , inv_sister : 0.35
# inv_nephew ←  brother , uncle , brother : 0.27
# aunt ←  brother , uncle , sister : 0.64
# aunt ←  brother , uncle , inv_brother : 0.27
# aunt ←  brother , uncle , inv_sister : 0.33
# niece ←  brother , wife , daughter : 0.47
# nephew ←  brother , wife , son : 0.36
# inv_sister ←  brother , inv_aunt , aunt : 0.5
# nephew ←  brother , inv_aunt , brother : 0.44
# niece ←  brother , inv_aunt , sister : 0.53
# brother ←  brother , inv_aunt , uncle : 0.5
# nephew ←  brother , inv_aunt , inv_brother : 0.45
# inv_sister ←  brother , inv_aunt , inv_nephew : 0.36
# sister ←  brother , inv_aunt , inv_niece : 0.34
# nephew ←  brother , inv_aunt , inv_sister : 0.46
# aunt ←  brother , inv_brother , aunt : 0.85
# brother ←  brother , inv_brother , brother : 0.7
# niece ←  brother , inv_brother , daughter : 0.63
# father ←  brother , inv_brother , father : 0.45
# mother ←  brother , inv_brother , mother : 0.62
# nephew ←  brother , inv_brother , nephew : 0.51
# niece ←  brother , inv_brother , niece : 0.64
# sister ←  brother , inv_brother , sister : 0.58
# nephew ←  brother , inv_brother , son : 0.65
# inv_niece ←  brother , inv_brother , uncle : 0.39
# niece ←  brother , inv_brother , inv_aunt : 0.43
# sister ←  brother , inv_brother , inv_brother : 0.37
# mother ←  brother , inv_brother , inv_daughter : 0.28
# nephew ←  brother , inv_brother , inv_father : 0.33
# nephew ←  brother , inv_brother , inv_mother : 0.32
# aunt ←  brother , inv_brother , inv_nephew : 0.37
# aunt ←  brother , inv_brother , inv_niece : 0.3
# brother ←  brother , inv_brother , inv_sister : 0.33
# inv_daughter ←  brother , inv_brother , inv_son : 0.37
# niece ←  brother , inv_brother , inv_uncle : 0.28
# inv_niece ←  brother , inv_daughter , brother : 0.32
# sister ←  brother , inv_daughter , daughter : 0.42
# aunt ←  brother , inv_daughter , sister : 0.58
# inv_sister ←  brother , inv_daughter , son : 0.49
# aunt ←  brother , inv_daughter , inv_brother : 0.33
# inv_sister ←  brother , inv_daughter , inv_father : 0.42
# mother ←  brother , inv_daughter , inv_husband : 0.79
# inv_niece ←  brother , inv_daughter , inv_sister : 0.45
# inv_sister ←  brother , inv_father , aunt : 0.47
# inv_aunt ←  brother , inv_father , brother : 0.43
# niece ←  brother , inv_father , sister : 0.44
# brother ←  brother , inv_father , uncle : 0.51
# inv_aunt ←  brother , inv_father , inv_brother : 0.33
# sister ←  brother , inv_father , inv_nephew : 0.31
# inv_sister ←  brother , inv_father , inv_niece : 0.35
# nephew ←  brother , inv_father , inv_sister : 0.34
# niece ←  brother , inv_husband , daughter : 0.54
# niece ←  brother , inv_husband , niece : 0.43
# nephew ←  brother , inv_husband , son : 0.36
# inv_sister ←  brother , inv_mother , aunt : 0.49
# nephew ←  brother , inv_mother , brother : 0.51
# niece ←  brother , inv_mother , sister : 0.61
# brother ←  brother , inv_mother , uncle : 0.46
# nephew ←  brother , inv_mother , inv_brother : 0.33
# inv_sister ←  brother , inv_mother , inv_nephew : 0.31
# nephew ←  brother , inv_mother , inv_sister : 0.46
# inv_niece ←  brother , inv_nephew , brother : 0.4
# aunt ←  brother , inv_nephew , sister : 0.62
# aunt ←  brother , inv_nephew , inv_brother : 0.33
# inv_niece ←  brother , inv_nephew , inv_sister : 0.27
# uncle ←  brother , inv_niece , brother : 0.36
# aunt ←  brother , inv_niece , sister : 0.65
# aunt ←  brother , inv_niece , inv_brother : 0.28
# aunt ←  brother , inv_niece , inv_sister : 0.42
# aunt ←  brother , inv_sister , aunt : 0.88
# brother ←  brother , inv_sister , brother : 0.74
# niece ←  brother , inv_sister , daughter : 0.69
# father ←  brother , inv_sister , father : 0.46
# mother ←  brother , inv_sister , mother : 0.58
# nephew ←  brother , inv_sister , nephew : 0.54
# niece ←  brother , inv_sister , niece : 0.72
# sister ←  brother , inv_sister , sister : 0.53
# nephew ←  brother , inv_sister , son : 0.81
# inv_niece ←  brother , inv_sister , uncle : 0.47
# niece ←  brother , inv_sister , inv_aunt : 0.51
# sister ←  brother , inv_sister , inv_brother : 0.34
# mother ←  brother , inv_sister , inv_daughter : 0.31
# nephew ←  brother , inv_sister , inv_father : 0.51
# nephew ←  brother , inv_sister , inv_mother : 0.46
# aunt ←  brother , inv_sister , inv_nephew : 0.38
# aunt ←  brother , inv_sister , inv_niece : 0.38
# brother ←  brother , inv_sister , inv_sister : 0.45
# inv_daughter ←  brother , inv_sister , inv_son : 0.43
# inv_aunt ←  brother , inv_sister , inv_uncle : 0.35
# inv_nephew ←  brother , inv_son , brother : 0.44
# inv_brother ←  brother , inv_son , daughter : 0.6
# aunt ←  brother , inv_son , sister : 0.85
# inv_brother ←  brother , inv_son , son : 0.63
# mother ←  brother , inv_son , wife : 0.54
# inv_nephew ←  brother , inv_son , inv_brother : 0.42
# inv_brother ←  brother , inv_son , inv_father : 0.6
# brother ←  daughter , inv_niece , inv_sister : 0.28
# inv_mother ←  daughter , inv_niece , inv_uncle : 0.22
# sister ←  daughter , inv_sister , aunt : 0.35
# inv_father ←  daughter , inv_sister , brother : 0.41
# inv_husband ←  daughter , inv_sister , mother : 0.72
# daughter ←  daughter , inv_sister , sister : 0.5
# brother ←  daughter , inv_sister , uncle : 0.4
# daughter ←  daughter , inv_sister , inv_brother : 0.38
# inv_husband ←  daughter , inv_sister , inv_daughter : 0.32
# daughter ←  daughter , inv_sister , inv_sister : 0.41
# aunt ←  daughter , inv_son , aunt : 0.71
# brother ←  daughter , inv_son , brother : 0.44
# son ←  daughter , inv_son , son : 0.25
# daughter ←  daughter , inv_uncle , aunt : 0.32
# inv_mother ←  daughter , inv_uncle , father : 0.3
# inv_mother ←  daughter , inv_uncle , inv_daughter : 0.35
# daughter ←  daughter , inv_uncle , inv_nephew : 0.21
# aunt ←  father , daughter , aunt : 0.69
# brother ←  father , daughter , brother : 0.49
# mother ←  father , daughter , mother : 0.35
# inv_nephew ←  father , daughter , uncle : 0.43
# sister ←  father , daughter , inv_brother : 0.24
# inv_nephew ←  father , daughter , inv_niece : 0.36
# brother ←  father , daughter , inv_sister : 0.26
# aunt ←  father , father , daughter : 0.3
# uncle ←  father , father , son : 0.3
# aunt ←  father , father , inv_father : 0.25
# inv_nephew ←  father , husband , inv_sister : 0.27
# aunt ←  father , mother , daughter : 0.45
# inv_niece ←  father , mother , son : 0.47
# aunt ←  father , mother , inv_mother : 0.3
# aunt ←  father , nephew , aunt : 0.63
# aunt ←  father , niece , aunt : 0.57
# inv_nephew ←  father , niece , uncle : 0.36
# inv_nephew ←  father , niece , inv_niece : 0.26
# inv_nephew ←  father , sister , inv_sister : 0.32
# aunt ←  father , son , aunt : 0.7
# brother ←  father , son , brother : 0.58
# niece ←  father , son , daughter : 0.55
# inv_daughter ←  father , son , mother : 0.38
# nephew ←  father , son , nephew : 0.42
# niece ←  father , son , niece : 0.57
# sister ←  father , son , sister : 0.37
# nephew ←  father , son , son : 0.4
# inv_nephew ←  father , son , uncle : 0.6
# nephew ←  father , son , inv_aunt : 0.22
# sister ←  father , son , inv_brother : 0.3
# nephew ←  father , son , inv_mother : 0.25
# inv_nephew ←  father , son , inv_nephew : 0.34
# inv_nephew ←  father , son , inv_niece : 0.46
# brother ←  father , son , inv_sister : 0.34
# inv_aunt ←  father , son , inv_uncle : 0.28
# inv_sister ←  father , wife , daughter : 0.36
# brother ←  father , wife , son : 0.47
# aunt ←  father , inv_aunt , aunt : 0.67
# inv_niece ←  father , inv_aunt , uncle : 0.29
# aunt ←  father , inv_aunt , inv_nephew : 0.25
# inv_nephew ←  father , inv_aunt , inv_niece : 0.31
# aunt ←  father , inv_daughter , daughter : 0.31
# inv_niece ←  father , inv_daughter , son : 0.37
# inv_nephew ←  father , inv_daughter , inv_father : 0.17
# aunt ←  father , inv_father , aunt : 0.79
# brother ←  father , inv_father , brother : 0.54
# niece ←  father , inv_father , daughter : 0.5
# father ←  father , inv_father , father : 0.48
# mother ←  father , inv_father , mother : 0.59
# nephew ←  father , inv_father , nephew : 0.34
# niece ←  father , inv_father , niece : 0.43
# inv_brother ←  father , inv_father , sister : 0.38
# nephew ←  father , inv_father , son : 0.53
# inv_nephew ←  father , inv_father , uncle : 0.64
# sister ←  father , inv_father , inv_brother : 0.3
# inv_uncle ←  father , inv_father , inv_father : 0.33
# nephew ←  father , inv_father , inv_mother : 0.31
# inv_nephew ←  father , inv_father , inv_nephew : 0.42
# inv_nephew ←  father , inv_father , inv_niece : 0.63
# brother ←  father , inv_father , inv_sister : 0.3
# brother ←  father , inv_husband , son : 0.36
# aunt ←  father , inv_mother , aunt : 0.59
# brother ←  father , inv_mother , brother : 0.64
# inv_daughter ←  father , inv_mother , mother : 0.3
# nephew ←  father , inv_mother , nephew : 0.35
# niece ←  father , inv_mother , niece : 0.33
# sister ←  father , inv_mother , sister : 0.4
# nephew ←  father , inv_mother , son : 0.35
# inv_niece ←  father , inv_mother , uncle : 0.36
# inv_niece ←  father , inv_mother , inv_nephew : 0.36
# inv_niece ←  father , inv_mother , inv_niece : 0.32
# brother ←  father , inv_mother , inv_sister : 0.32
# inv_nephew ←  father , inv_sister , brother : 0.3
# aunt ←  father , inv_sister , inv_brother : 0.27
# aunt ←  father , inv_son , daughter : 0.48
# uncle ←  father , inv_son , son : 0.36
# aunt ←  father , inv_son , inv_father : 0.28
# aunt ←  father , inv_son , inv_mother : 0.35
# aunt ←  father , inv_uncle , aunt : 0.6
# inv_niece ←  father , inv_uncle , uncle : 0.49
# inv_niece ←  father , inv_uncle , inv_niece : 0.4
# inv_sister ←  father , inv_wife , daughter : 0.43
# inv_mother ←  husband , daughter , brother : 0.49
# daughter ←  husband , daughter , sister : 0.52
# inv_mother ←  husband , daughter , inv_brother : 0.45
# daughter ←  husband , daughter , inv_sister : 0.29
# inv_mother ←  husband , son , brother : 0.71
# inv_mother ←  husband , son , sister : 0.51
# inv_mother ←  husband , son , inv_brother : 0.65
# inv_mother ←  husband , son , inv_sister : 0.54
# inv_mother ←  husband , inv_father , brother : 0.73
# daughter ←  husband , inv_father , sister : 0.76
# inv_mother ←  husband , inv_father , inv_brother : 0.47
# inv_mother ←  husband , inv_father , inv_sister : 0.39
# inv_mother ←  husband , inv_mother , brother : 0.46
# daughter ←  husband , inv_mother , sister : 0.39
# inv_mother ←  husband , inv_mother , inv_brother : 0.62
# inv_mother ←  husband , inv_mother , inv_sister : 0.41
# aunt ←  mother , daughter , aunt : 0.8
# brother ←  mother , daughter , brother : 0.45
# niece ←  mother , daughter , daughter : 0.34
# mother ←  mother , daughter , mother : 0.38
# nephew ←  mother , daughter , nephew : 0.37
# sister ←  mother , daughter , sister : 0.32
# nephew ←  mother , daughter , son : 0.48
# inv_nephew ←  mother , daughter , uncle : 0.56
# inv_uncle ←  mother , daughter , inv_aunt : 0.31
# inv_brother ←  mother , daughter , inv_brother : 0.28
# inv_uncle ←  mother , daughter , inv_father : 0.38
# nephew ←  mother , daughter , inv_mother : 0.26
# inv_nephew ←  mother , daughter , inv_nephew : 0.39
# inv_nephew ←  mother , daughter , inv_niece : 0.49
# inv_niece ←  mother , father , son : 0.6
# inv_niece ←  mother , father , inv_father : 0.45
# inv_nephew ←  mother , husband , brother : 0.6
# inv_brother ←  mother , husband , daughter : 0.41
# brother ←  mother , husband , son : 0.34
# inv_nephew ←  mother , husband , inv_brother : 0.28
# aunt ←  mother , husband , inv_sister : 0.33
# aunt ←  mother , mother , daughter : 0.57
# inv_niece ←  mother , mother , son : 0.74
# aunt ←  mother , mother , inv_mother : 0.38
# aunt ←  mother , nephew , aunt : 0.7
# inv_nephew ←  mother , nephew , uncle : 0.56
# inv_nephew ←  mother , nephew , inv_nephew : 0.41
# inv_nephew ←  mother , nephew , inv_niece : 0.45
# aunt ←  mother , niece , aunt : 0.75
# inv_nephew ←  mother , niece , uncle : 0.71
# inv_nephew ←  mother , niece , inv_nephew : 0.51
# inv_nephew ←  mother , niece , inv_niece : 0.58
# inv_nephew ←  mother , sister , brother : 0.41
# aunt ←  mother , sister , sister : 0.48
# inv_nephew ←  mother , sister , inv_brother : 0.29
# aunt ←  mother , sister , inv_sister : 0.37
# aunt ←  mother , son , aunt : 0.76
# brother ←  mother , son , brother : 0.64
# niece ←  mother , son , daughter : 0.56
# mother ←  mother , son , mother : 0.49
# nephew ←  mother , son , nephew : 0.72
# niece ←  mother , son , niece : 0.61
# sister ←  mother , son , sister : 0.52
# nephew ←  mother , son , son : 0.81
# inv_nephew ←  mother , son , uncle : 0.74
# nephew ←  mother , son , inv_aunt : 0.35
# sister ←  mother , son , inv_brother : 0.35
# inv_uncle ←  mother , son , inv_father : 0.46
# niece ←  mother , son , inv_mother : 0.35
# inv_niece ←  mother , son , inv_nephew : 0.35
# inv_nephew ←  mother , son , inv_niece : 0.48
# brother ←  mother , son , inv_sister : 0.35
# nephew ←  mother , son , inv_uncle : 0.29
# inv_nephew ←  mother , wife , brother : 0.48
# inv_brother ←  mother , wife , daughter : 0.5
# brother ←  mother , wife , son : 0.51
# aunt ←  mother , inv_aunt , aunt : 0.78
# inv_nephew ←  mother , inv_aunt , uncle : 0.55
# inv_nephew ←  mother , inv_aunt , inv_nephew : 0.35
# inv_nephew ←  mother , inv_aunt , inv_niece : 0.54
# inv_niece ←  mother , inv_daughter , son : 0.35
# aunt ←  mother , inv_father , aunt : 0.86
# brother ←  mother , inv_father , brother : 0.54
# niece ←  mother , inv_father , daughter : 0.55
# mother ←  mother , inv_father , mother : 0.49
# nephew ←  mother , inv_father , nephew : 0.52
# niece ←  mother , inv_father , niece : 0.31
# sister ←  mother , inv_father , sister : 0.49
# nephew ←  mother , inv_father , son : 0.76
# inv_nephew ←  mother , inv_father , uncle : 0.78
# inv_uncle ←  mother , inv_father , inv_aunt : 0.23
# inv_brother ←  mother , inv_father , inv_brother : 0.29
# inv_uncle ←  mother , inv_father , inv_father : 0.57
# niece ←  mother , inv_father , inv_mother : 0.29
# inv_nephew ←  mother , inv_father , inv_nephew : 0.54
# inv_nephew ←  mother , inv_father , inv_niece : 0.73
# brother ←  mother , inv_father , inv_sister : 0.23
# inv_nephew ←  mother , inv_husband , brother : 0.58
# brother ←  mother , inv_husband , son : 0.37
# mother ←  mother , inv_husband , inv_husband : 0.57
# aunt ←  mother , inv_mother , aunt : 0.71
# brother ←  mother , inv_mother , brother : 0.75
# niece ←  mother , inv_mother , daughter : 0.48
# mother ←  mother , inv_mother , mother : 0.43
# nephew ←  mother , inv_mother , nephew : 0.74
# niece ←  mother , inv_mother , niece : 0.39
# sister ←  mother , inv_mother , sister : 0.6
# nephew ←  mother , inv_mother , son : 0.87
# inv_nephew ←  mother , inv_mother , uncle : 0.37
# nephew ←  mother , inv_mother , inv_aunt : 0.51
# sister ←  mother , inv_mother , inv_brother : 0.35
# nephew ←  mother , inv_mother , inv_father : 0.47
# inv_niece ←  mother , inv_mother , inv_nephew : 0.37
# inv_nephew ←  mother , inv_mother , inv_niece : 0.29
# brother ←  mother , inv_mother , inv_sister : 0.41
# inv_nephew ←  mother , inv_sister , brother : 0.38
# aunt ←  mother , inv_sister , sister : 0.55
# aunt ←  mother , inv_sister , inv_brother : 0.23
# aunt ←  mother , inv_son , daughter : 0.44
# inv_niece ←  mother , inv_son , son : 0.37
# inv_nephew ←  mother , inv_son , inv_father : 0.28
# aunt ←  mother , inv_son , inv_mother : 0.35
# aunt ←  mother , inv_uncle , aunt : 0.8
# inv_nephew ←  mother , inv_uncle , uncle : 0.45
# inv_nephew ←  mother , inv_uncle , inv_nephew : 0.32
# inv_nephew ←  mother , inv_uncle , inv_niece : 0.37
# inv_nephew ←  mother , inv_wife , brother : 0.48
# inv_brother ←  mother , inv_wife , daughter : 0.38
# aunt ←  mother , inv_wife , sister : 0.5
# brother ←  mother , inv_wife , son : 0.39
# inv_niece ←  mother , inv_wife , inv_brother : 0.41
# inv_brother ←  mother , inv_wife , inv_father : 0.26
# inv_niece ←  mother , inv_wife , inv_sister : 0.27
# aunt ←  nephew , aunt , aunt : 0.69
# brother ←  nephew , aunt , brother : 0.68
# niece ←  nephew , aunt , daughter : 0.65
# mother ←  nephew , aunt , mother : 0.37
# nephew ←  nephew , aunt , nephew : 0.5
# niece ←  nephew , aunt , niece : 0.54
# sister ←  nephew , aunt , sister : 0.43
# nephew ←  nephew , aunt , son : 0.4
# inv_nephew ←  nephew , aunt , uncle : 0.38
# niece ←  nephew , aunt , inv_aunt : 0.34
# brother ←  nephew , aunt , inv_brother : 0.29
# niece ←  nephew , aunt , inv_mother : 0.36
# brother ←  nephew , aunt , inv_sister : 0.3
# nephew ←  nephew , aunt , inv_uncle : 0.23
# aunt ←  nephew , brother , aunt : 0.32
# nephew ←  nephew , brother , brother : 0.43
# niece ←  nephew , brother , sister : 0.35
# brother ←  nephew , brother , uncle : 0.22
# nephew ←  nephew , brother , inv_brother : 0.33
# nephew ←  nephew , brother , inv_sister : 0.35
# niece ←  nephew , daughter , aunt : 0.5
# nephew ←  nephew , daughter , father : 0.56
# inv_aunt ←  nephew , daughter , inv_nephew : 0.27
# inv_aunt ←  nephew , daughter , inv_niece : 0.35
# aunt ←  nephew , father , aunt : 0.68
# brother ←  nephew , father , brother : 0.67
# niece ←  nephew , father , daughter : 0.67
# inv_brother ←  nephew , father , husband : 0.33
# inv_daughter ←  nephew , father , mother : 0.42
# nephew ←  nephew , father , nephew : 0.4
# niece ←  nephew , father , niece : 0.41
# sister ←  nephew , father , sister : 0.45
# nephew ←  nephew , father , son : 0.61
# inv_nephew ←  nephew , father , uncle : 0.55
# sister ←  nephew , father , inv_brother : 0.27
# nephew ←  nephew , father , inv_father : 0.25
# inv_brother ←  nephew , father , inv_husband : 0.38
# nephew ←  nephew , father , inv_mother : 0.37
# aunt ←  nephew , father , inv_nephew : 0.36
# inv_nephew ←  nephew , father , inv_niece : 0.33
# brother ←  nephew , father , inv_sister : 0.3
# brother ←  nephew , father , inv_wife : 0.33
# aunt ←  nephew , mother , aunt : 0.67
# brother ←  nephew , mother , brother : 0.65
# niece ←  nephew , mother , daughter : 0.58
# inv_brother ←  nephew , mother , husband : 0.28
# nephew ←  nephew , mother , nephew : 0.36
# sister ←  nephew , mother , sister : 0.42
# nephew ←  nephew , mother , son : 0.73
# inv_niece ←  nephew , mother , uncle : 0.38
# brother ←  nephew , mother , inv_brother : 0.27
# nephew ←  nephew , mother , inv_father : 0.31
# nephew ←  nephew , mother , inv_mother : 0.55
# inv_niece ←  nephew , mother , inv_nephew : 0.29
# inv_nephew ←  nephew , mother , inv_niece : 0.29
# brother ←  nephew , mother , inv_sister : 0.27
# nephew ←  nephew , mother , inv_uncle : 0.3
# brother ←  nephew , mother , inv_wife : 0.34
# niece ←  nephew , nephew , aunt : 0.49
# nephew ←  nephew , nephew , father : 0.62
# nephew ←  nephew , nephew , uncle : 0.54
# niece ←  nephew , nephew , inv_nephew : 0.22
# niece ←  nephew , niece , aunt : 0.52
# nephew ←  nephew , niece , father : 0.67
# nephew ←  nephew , niece , uncle : 0.45
# nephew ←  nephew , niece , inv_daughter : 0.33
# nephew ←  nephew , niece , inv_nephew : 0.22
# niece ←  nephew , niece , inv_niece : 0.3
# nephew ←  nephew , niece , inv_son : 0.36
# sister ←  nephew , sister , aunt : 0.35
# nephew ←  nephew , sister , brother : 0.65
# niece ←  nephew , sister , sister : 0.52
# brother ←  nephew , sister , uncle : 0.31
# nephew ←  nephew , sister , inv_brother : 0.32
# nephew ←  nephew , sister , inv_sister : 0.43
# niece ←  nephew , son , aunt : 0.54
# nephew ←  nephew , son , uncle : 0.61
# nephew ←  nephew , son , inv_nephew : 0.26
# niece ←  nephew , son , inv_niece : 0.31
# aunt ←  nephew , uncle , aunt : 0.72
# brother ←  nephew , uncle , brother : 0.61
# niece ←  nephew , uncle , daughter : 0.55
# inv_daughter ←  nephew , uncle , mother : 0.43
# nephew ←  nephew , uncle , nephew : 0.38
# niece ←  nephew , uncle , niece : 0.46
# sister ←  nephew , uncle , sister : 0.42
# nephew ←  nephew , uncle , son : 0.5
# inv_nephew ←  nephew , uncle , uncle : 0.5
# nephew ←  nephew , uncle , inv_mother : 0.36
# inv_nephew ←  nephew , uncle , inv_nephew : 0.26
# inv_nephew ←  nephew , uncle , inv_niece : 0.34
# brother ←  nephew , uncle , inv_sister : 0.29
# niece ←  nephew , inv_aunt , aunt : 0.41
# nephew ←  nephew , inv_aunt , father : 0.48
# nephew ←  nephew , inv_aunt , uncle : 0.38
# inv_aunt ←  nephew , inv_aunt , inv_nephew : 0.37
# inv_aunt ←  nephew , inv_aunt , inv_niece : 0.28
# sister ←  nephew , inv_brother , aunt : 0.31
# nephew ←  nephew , inv_brother , brother : 0.61
# niece ←  nephew , inv_brother , sister : 0.46
# nephew ←  nephew , inv_brother , inv_brother : 0.43
# sister ←  nephew , inv_brother , inv_nephew : 0.2
# nephew ←  nephew , inv_brother , inv_sister : 0.41
# aunt ←  nephew , inv_daughter , aunt : 0.81
# brother ←  nephew , inv_daughter , brother : 0.56
# niece ←  nephew , inv_daughter , daughter : 0.68
# niece ←  nephew , inv_daughter , niece : 0.43
# sister ←  nephew , inv_daughter , sister : 0.48
# nephew ←  nephew , inv_daughter , son : 0.65
# inv_nephew ←  nephew , inv_daughter , uncle : 0.54
# sister ←  nephew , inv_daughter , inv_brother : 0.33
# inv_uncle ←  nephew , inv_daughter , inv_father : 0.27
# nephew ←  nephew , inv_daughter , inv_mother : 0.34
# aunt ←  nephew , inv_daughter , inv_nephew : 0.4
# inv_nephew ←  nephew , inv_daughter , inv_niece : 0.31
# niece ←  nephew , inv_father , aunt : 0.65
# nephew ←  nephew , inv_father , father : 0.68
# niece ←  nephew , inv_father , mother : 0.41
# nephew ←  nephew , inv_father , uncle : 0.66
# nephew ←  nephew , inv_father , inv_daughter : 0.37
# nephew ←  nephew , inv_father , inv_nephew : 0.35
# niece ←  nephew , inv_father , inv_niece : 0.32
# nephew ←  nephew , inv_father , inv_son : 0.39
# niece ←  nephew , inv_mother , aunt : 0.49
# nephew ←  nephew , inv_mother , father : 0.57
# nephew ←  nephew , inv_mother , uncle : 0.43
# inv_aunt ←  nephew , inv_mother , inv_nephew : 0.31
# niece ←  nephew , inv_mother , inv_niece : 0.32
# aunt ←  nephew , inv_nephew , aunt : 0.79
# brother ←  nephew , inv_nephew , brother : 0.65
# niece ←  nephew , inv_nephew , daughter : 0.65
# father ←  nephew , inv_nephew , father : 0.54
# inv_daughter ←  nephew , inv_nephew , mother : 0.48
# inv_aunt ←  nephew , inv_nephew , nephew : 0.42
# niece ←  nephew , inv_nephew , niece : 0.65
# sister ←  nephew , inv_nephew , sister : 0.51
# nephew ←  nephew , inv_nephew , son : 0.5
# inv_nephew ←  nephew , inv_nephew , uncle : 0.5
# niece ←  nephew , inv_nephew , inv_aunt : 0.4
# sister ←  nephew , inv_nephew , inv_brother : 0.27
# mother ←  nephew , inv_nephew , inv_daughter : 0.33
# nephew ←  nephew , inv_nephew , inv_mother : 0.39
# aunt ←  nephew , inv_nephew , inv_nephew : 0.31
# inv_nephew ←  nephew , inv_nephew , inv_niece : 0.4
# brother ←  nephew , inv_nephew , inv_sister : 0.28
# inv_daughter ←  nephew , inv_nephew , inv_son : 0.31
# nephew ←  nephew , inv_nephew , inv_uncle : 0.28
# aunt ←  nephew , inv_niece , aunt : 0.71
# brother ←  nephew , inv_niece , brother : 0.67
# niece ←  nephew , inv_niece , daughter : 0.61
# father ←  nephew , inv_niece , father : 0.45
# inv_daughter ←  nephew , inv_niece , mother : 0.42
# nephew ←  nephew , inv_niece , nephew : 0.45
# niece ←  nephew , inv_niece , niece : 0.54
# sister ←  nephew , inv_niece , sister : 0.5
# nephew ←  nephew , inv_niece , son : 0.52
# inv_nephew ←  nephew , inv_niece , uncle : 0.36
# niece ←  nephew , inv_niece , inv_aunt : 0.4
# brother ←  nephew , inv_niece , inv_brother : 0.32
# mother ←  nephew , inv_niece , inv_daughter : 0.27
# niece ←  nephew , inv_niece , inv_mother : 0.37
# inv_niece ←  nephew , inv_niece , inv_nephew : 0.33
# inv_nephew ←  nephew , inv_niece , inv_niece : 0.29
# brother ←  nephew , inv_niece , inv_sister : 0.31
# inv_daughter ←  nephew , inv_niece , inv_son : 0.33
# nephew ←  nephew , inv_niece , inv_uncle : 0.25
# sister ←  nephew , inv_sister , aunt : 0.37
# nephew ←  nephew , inv_sister , brother : 0.83
# brother ←  nephew , inv_sister , father : 0.45
# inv_brother ←  nephew , inv_sister , mother : 0.32
# niece ←  nephew , inv_sister , sister : 0.59
# nephew ←  nephew , inv_sister , inv_brother : 0.47
# inv_sister ←  nephew , inv_sister , inv_nephew : 0.25
# nephew ←  nephew , inv_sister , inv_sister : 0.49
# aunt ←  nephew , inv_son , aunt : 0.71
# brother ←  nephew , inv_son , brother : 0.61
# niece ←  nephew , inv_son , daughter : 0.64
# inv_brother ←  nephew , inv_son , husband : 0.47
# inv_daughter ←  nephew , inv_son , mother : 0.39
# nephew ←  nephew , inv_son , nephew : 0.41
# niece ←  nephew , inv_son , niece : 0.48
# inv_brother ←  nephew , inv_son , sister : 0.42
# nephew ←  nephew , inv_son , son : 0.8
# inv_nephew ←  nephew , inv_son , uncle : 0.63
# inv_brother ←  nephew , inv_son , inv_brother : 0.35
# nephew ←  nephew , inv_son , inv_father : 0.34
# nephew ←  nephew , inv_son , inv_mother : 0.58
# inv_nephew ←  nephew , inv_son , inv_nephew : 0.39
# inv_nephew ←  nephew , inv_son , inv_niece : 0.45
# brother ←  nephew , inv_son , inv_sister : 0.23
# niece ←  nephew , inv_uncle , aunt : 0.68
# nephew ←  nephew , inv_uncle , father : 0.71
# nephew ←  nephew , inv_uncle , uncle : 0.65
# nephew ←  nephew , inv_uncle , inv_daughter : 0.38
# niece ←  nephew , inv_uncle , inv_nephew : 0.3
# niece ←  nephew , inv_uncle , inv_niece : 0.38
# nephew ←  nephew , inv_uncle , inv_son : 0.43
# aunt ←  niece , aunt , aunt : 0.78
# brother ←  niece , aunt , brother : 0.67
# niece ←  niece , aunt , daughter : 0.74
# father ←  niece , aunt , father : 0.53
# mother ←  niece , aunt , mother : 0.7
# nephew ←  niece , aunt , nephew : 0.46
# niece ←  niece , aunt , niece : 0.6
# sister ←  niece , aunt , sister : 0.44
# nephew ←  niece , aunt , son : 0.53
# inv_nephew ←  niece , aunt , uncle : 0.47
# niece ←  niece , aunt , inv_aunt : 0.44
# sister ←  niece , aunt , inv_brother : 0.29
# mother ←  niece , aunt , inv_daughter : 0.34
# nephew ←  niece , aunt , inv_father : 0.27
# niece ←  niece , aunt , inv_mother : 0.46
# inv_nephew ←  niece , aunt , inv_nephew : 0.28
# inv_nephew ←  niece , aunt , inv_niece : 0.33
# sister ←  niece , aunt , inv_sister : 0.29
# inv_daughter ←  niece , aunt , inv_son : 0.27
# niece ←  niece , aunt , inv_uncle : 0.22
# sister ←  niece , brother , aunt : 0.25
# niece ←  niece , brother , sister : 0.37
# inv_aunt ←  niece , brother , inv_brother : 0.28
# sister ←  niece , brother , inv_nephew : 0.21
# nephew ←  niece , brother , inv_sister : 0.29
# inv_aunt ←  niece , daughter , aunt : 0.39
# nephew ←  niece , daughter , father : 0.54
# nephew ←  niece , daughter , uncle : 0.41
# inv_aunt ←  niece , daughter , inv_nephew : 0.44
# inv_aunt ←  niece , daughter , inv_niece : 0.5
# aunt ←  niece , father , aunt : 0.73
# brother ←  niece , father , brother : 0.49
# niece ←  niece , father , daughter : 0.72
# mother ←  niece , father , mother : 0.31
# sister ←  niece , father , sister : 0.45
# nephew ←  niece , father , son : 0.57
# inv_nephew ←  niece , father , uncle : 0.53
# sister ←  niece , father , inv_brother : 0.29
# aunt ←  niece , father , inv_daughter : 0.24
# inv_aunt ←  niece , father , inv_father : 0.27
# inv_brother ←  niece , father , inv_husband : 0.32
# nephew ←  niece , father , inv_mother : 0.34
# aunt ←  niece , father , inv_nephew : 0.36
# inv_nephew ←  niece , father , inv_niece : 0.3
# sister ←  niece , father , inv_sister : 0.28
# aunt ←  niece , mother , aunt : 0.62
# brother ←  niece , mother , brother : 0.52
# niece ←  niece , mother , daughter : 0.56
# inv_brother ←  niece , mother , husband : 0.25
# sister ←  niece , mother , sister : 0.42
# nephew ←  niece , mother , son : 0.64
# inv_niece ←  niece , mother , uncle : 0.46
# sister ←  niece , mother , inv_brother : 0.29
# nephew ←  niece , mother , inv_father : 0.28
# nephew ←  niece , mother , inv_mother : 0.41
# inv_nephew ←  niece , mother , inv_nephew : 0.35
# inv_nephew ←  niece , mother , inv_niece : 0.24
# brother ←  niece , mother , inv_wife : 0.29
# niece ←  niece , nephew , aunt : 0.38
# nephew ←  niece , nephew , father : 0.48
# nephew ←  niece , nephew , uncle : 0.44
# inv_aunt ←  niece , nephew , inv_nephew : 0.4
# niece ←  niece , niece , aunt : 0.49
# nephew ←  niece , niece , father : 0.56
# nephew ←  niece , niece , uncle : 0.49
# inv_aunt ←  niece , niece , inv_nephew : 0.33
# niece ←  niece , niece , inv_niece : 0.25
# sister ←  niece , sister , aunt : 0.39
# nephew ←  niece , sister , brother : 0.61
# niece ←  niece , sister , sister : 0.55
# inv_aunt ←  niece , sister , inv_brother : 0.4
# inv_aunt ←  niece , sister , inv_sister : 0.36
# niece ←  niece , son , aunt : 0.48
# nephew ←  niece , son , father : 0.48
# nephew ←  niece , son , uncle : 0.58
# nephew ←  niece , son , inv_nephew : 0.3
# nephew ←  niece , son , inv_niece : 0.26
# aunt ←  niece , uncle , aunt : 0.67
# brother ←  niece , uncle , brother : 0.54
# niece ←  niece , uncle , daughter : 0.47
# inv_daughter ←  niece , uncle , mother : 0.42
# nephew ←  niece , uncle , nephew : 0.35
# niece ←  niece , uncle , niece : 0.45
# sister ←  niece , uncle , sister : 0.42
# nephew ←  niece , uncle , son : 0.51
# inv_nephew ←  niece , uncle , uncle : 0.4
# inv_aunt ←  niece , uncle , inv_aunt : 0.25
# sister ←  niece , uncle , inv_brother : 0.23
# nephew ←  niece , uncle , inv_mother : 0.35
# inv_nephew ←  niece , uncle , inv_niece : 0.25
# brother ←  niece , uncle , inv_sister : 0.28
# inv_aunt ←  niece , uncle , inv_uncle : 0.26
# inv_aunt ←  niece , inv_aunt , aunt : 0.48
# nephew ←  niece , inv_aunt , father : 0.46
# nephew ←  niece , inv_aunt , uncle : 0.38
# inv_aunt ←  niece , inv_aunt , inv_daughter : 0.38
# inv_aunt ←  niece , inv_aunt , inv_nephew : 0.61
# inv_aunt ←  niece , inv_aunt , inv_niece : 0.43
# sister ←  niece , inv_brother , aunt : 0.32
# niece ←  niece , inv_brother , sister : 0.38
# inv_aunt ←  niece , inv_brother , inv_brother : 0.3
# aunt ←  niece , inv_daughter , aunt : 0.87
# brother ←  niece , inv_daughter , brother : 0.47
# niece ←  niece , inv_daughter , daughter : 0.68
# niece ←  niece , inv_daughter , niece : 0.41
# sister ←  niece , inv_daughter , sister : 0.47
# nephew ←  niece , inv_daughter , son : 0.54
# inv_nephew ←  niece , inv_daughter , uncle : 0.39
# sister ←  niece , inv_daughter , inv_brother : 0.35
# aunt ←  niece , inv_daughter , inv_daughter : 0.27
# inv_aunt ←  niece , inv_daughter , inv_father : 0.22
# nephew ←  niece , inv_daughter , inv_mother : 0.26
# aunt ←  niece , inv_daughter , inv_nephew : 0.43
# inv_nephew ←  niece , inv_daughter , inv_niece : 0.26
# niece ←  niece , inv_father , aunt : 0.54
# nephew ←  niece , inv_father , father : 0.55
# nephew ←  niece , inv_father , uncle : 0.58
# nephew ←  niece , inv_father , inv_nephew : 0.29
# inv_aunt ←  niece , inv_father , inv_niece : 0.24
# ...
# mother ←  wife , daughter , aunt , mother : 0.48
# inv_father ←  wife , daughter , aunt , nephew : 0.34
# niece ←  wife , daughter , aunt , niece : 0.48
# inv_nephew ←  wife , daughter , aunt , uncle : 0.52
# inv_father ←  wife , daughter , aunt , inv_aunt : 0.22
# niece ←  wife , daughter , aunt , inv_mother : 0.36
# inv_brother ←  wife , daughter , aunt , inv_sister : 0.34
# inv_father ←  wife , daughter , aunt , inv_uncle : 0.18
# inv_father ←  wife , daughter , brother , inv_sister : 0.33
# inv_father ←  wife , daughter , daughter , inv_daughter : 0.55
# inv_father ←  wife , daughter , daughter , inv_niece : 0.32
# aunt ←  wife , daughter , father , aunt : 0.63
# inv_nephew ←  wife , daughter , father , uncle : 0.48
# aunt ←  wife , daughter , mother , aunt : 0.38
# inv_father ←  wife , son , inv_nephew , inv_aunt : 0.23
# inv_brother ←  wife , son , inv_nephew , inv_sister : 0.34
# nephew ←  wife , son , inv_nephew , inv_uncle : 0.24
# aunt ←  wife , son , inv_niece , aunt : 0.58
# inv_father ←  wife , son , inv_niece , nephew : 0.37
# daughter ←  wife , son , inv_niece , niece : 0.34
# nephew ←  wife , son , inv_niece , son : 0.55
# inv_father ←  wife , son , inv_niece , inv_aunt : 0.19
# nephew ←  wife , son , inv_niece , inv_mother : 0.25
# inv_father ←  wife , son , inv_niece , inv_uncle : 0.27
# inv_father ←  wife , son , inv_sister , brother : 0.52
# daughter ←  wife , son , inv_sister , sister : 0.6
# inv_father ←  wife , son , inv_sister , inv_brother : 0.35
# inv_father ←  wife , son , inv_sister , inv_sister : 0.48
# son ←  wife , son , inv_son , son : 0.34
# aunt ←  wife , uncle , nephew , aunt : 0.46
# niece ←  wife , wife , brother , niece : 0.46
# daughter ←  wife , wife , son , sister : 0.41
# inv_father ←  wife , wife , son , inv_brother : 0.43
# inv_father ←  wife , wife , son , inv_sister : 0.51
# daughter ←  wife , wife , inv_father , sister : 0.45
# inv_father ←  wife , wife , inv_father , inv_brother : 0.29
# inv_father ←  wife , wife , inv_father , inv_sister : 0.38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-847f9b1af22d> in <module>
#      11             body_ = all_body[idx]
#      12             inputs = torch.LongTensor([body_idx]).to(device)
# ---> 13             pred_head = rnn.predict_head(inputs)
#      14             prob_ = torch.softmax(pred_head.squeeze(0), dim=0)
#      15             max_head_ = head_rdict.idx2rel[prob_.argmax().item()]
#
# <ipython-input-34-c6287a110fd0> in predict_head(self, inputs)
#      26         hidden = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
#      27                      torch.zeros(num_layers, batch_size, hidden_size).to(device))
# ---> 28         out, (h,c) = self.lstm(inputs, hidden)
#      29         body_emb = out[:, -1, :]
#      30         # P(H, B)
#
# //anaconda3/envs/logic/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# //anaconda3/envs/logic/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     562             return self.forward_packed(input, hx)
#     563         else:
# --> 564             return self.forward_tensor(input, hx)
#     565
#     566 class GRU(RNNBase):
#
# //anaconda3/envs/logic/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     541         unsorted_indices = None
#     542
# --> 543         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     544
#     545         return output, self.permute_hidden(hidden, unsorted_indices)
#
# //anaconda3/envs/logic/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     524         if batch_sizes is None:
#     525             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 526                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     527         else:
#     528             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %%
def Query_B(body2head, query_body_list):
    """
    Answering Question: 
        Given body, what is the most probable head?
    """
    key = "|".join(query_body_list)
    head = body2head[key]
    head.sort(key=lambda x:x[1], reverse=True)
    return head

# %%
body_ = ['brother', 'brother', 'brother']
inputs = torch.LongTensor([body_idx]).to(device)
pred_head = rnn.predict_head(inputs)
prob_ = torch.softmax(pred_head.squeeze(0), dim=0)

# %%
# Test P(H, B)
import numpy as np
prob_matrix = np.zeros(shape=(len(all_head), len(all_body)))
for b_i, body_ in enumerate(all_body):
    PB = body2prob["|".join(body_)]
    PHB_l = body2head["|".join(body_)]
    for head_, phb in PHB_l:
        # P(H, B) = P(H|B) * P(B)
        p = PB * phb
        h_i = head2idx[head_]
        prob_matrix[h_i][b_i] = p

# %%
def get_phb(head, body, head2idx, body2idx, prob_matrix):
    # return P(H, B)
    h_i = head2idx[head]
    b_i = body2idx[body]
    return prob_matrix[h_i][b_i]

pb = body2prob["mother|son"]
for head in all_head:
    prob = get_point_prob(head, "mother|son", head2idx, body2idx, prob_matrix)
    print(head, prob/pb)
    
p = 0
for x, y in body2head["mother|son"]:
    p += y

body2head["mother|son"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-24cabebdc088> in <module>
#       5     return prob_matrix[h_i][b_i]
#       6
# ----> 7 pb = body2prob["mother|son"]
#       8 for head in all_head:
#       9     prob = get_point_prob(head, "mother|son", head2idx, body2idx, prob_matrix)
#
# KeyError: 'mother|son'

# %%
body2prob
# Out:
# {'aunt|aunt|aunt': 4.923704291572213e-06,
#  'aunt|aunt|brother': 8.48132811404371e-06,
#  'aunt|aunt|daughter': 9.357714911533061e-06,
#  'aunt|aunt|father': 3.177603925961798e-06,
#  'aunt|aunt|husband': 3.3719079029057475e-06,
#  'aunt|aunt|mother': 8.702436995438939e-06,
#  'aunt|aunt|nephew': 6.007424437346441e-05,
#  'aunt|aunt|niece': 9.094718719473115e-05,
#  'aunt|aunt|sister': 2.8603349620888105e-05,
#  'aunt|aunt|son': 1.3509112804450333e-05,
#  'aunt|aunt|uncle': 8.948142517529664e-05,
#  'aunt|aunt|wife': 2.3598115337646938e-08,
#  'aunt|brother|aunt': 3.0421850753619122e-06,
#  'aunt|brother|brother': 8.948594306490247e-06,
#  'aunt|brother|daughter': 7.827669935458852e-06,
#  'aunt|brother|father': 3.3190891994333213e-06,
#  'aunt|brother|husband': 5.0824499353398705e-08,
#  'aunt|brother|mother': 1.1038946893561496e-05,
#  'aunt|brother|nephew': 4.407104441009335e-05,
#  'aunt|brother|niece': 0.0001449565498939931,
#  'aunt|brother|sister': 2.6201641728567857e-05,
#  'aunt|brother|son': 6.441390311710728e-06,
#  'aunt|brother|uncle': 0.0001545548944112407,
#  'aunt|brother|wife': 1.1182537644764852e-05,
#  'aunt|daughter|aunt': 0.00016298826232388763,
#  'aunt|daughter|brother': 0.00014119925487116047,
#  'aunt|daughter|daughter': 2.9332023424050863e-05,
#  'aunt|daughter|father': 2.1353389365954406e-05,
#  'aunt|daughter|husband': 7.847356313031573e-05,
#  'aunt|daughter|mother': 5.0762565673233284e-05,
#  'aunt|daughter|nephew': 0.00017723262479113489,
#  'aunt|daughter|niece': 0.00015450842822165023,
#  'aunt|daughter|sister': 5.892196740075323e-05,
#  'aunt|daughter|son': 0.00015990697748691218,
#  'aunt|daughter|uncle': 0.0009237977947249565,
#  'aunt|daughter|wife': 2.4737554200942235e-07,
#  'aunt|father|aunt': 5.20522754520637e-06,
#  'father|daughter|nephew': 0.00047070545564028654,
#  'father|daughter|niece': 0.0005639184818424143,
#  'father|daughter|sister': 0.0006346613561308463,
#  'father|daughter|son': 0.0002963908626448635,
#  'father|daughter|uncle': 0.0019538491377975955,
#  'father|daughter|wife': 2.888097329842443e-05,
#  'father|father|aunt': 4.904717116744073e-05,
#  'father|father|brother': 3.513189968155844e-05,
#  'father|father|daughter': 0.00036273221644636067,
#  'father|father|father': 0.00020522637301666777,
#  'father|father|husband': 1.9232085801163583e-05,
#  'father|father|mother': 0.00015499483878736103,
#  'father|father|nephew': 0.00014695565733333774,
#  'father|father|niece': 0.00023696999672470281,
#  'father|father|sister': 7.827427317568923e-05,
#  'father|father|son': 0.00047337201593619877,
#  'father|father|uncle': 0.0005050733216825041,
#  'father|father|wife': 0.0002754345803304622,
#  'father|husband|aunt': 2.9838359723842207e-06,
#  'father|husband|brother': 6.080668348700273e-06,
#  'father|husband|daughter': 2.4884987308000737e-05,
#  'father|husband|father': 5.9926428638016e-06,
#  'father|husband|husband': 1.6044325554029953e-07,
#  'father|husband|mother': 7.57208720664009e-06,
#  'father|husband|nephew': 7.852047115074028e-06,
#  'father|husband|niece': 1.648033913284326e-05,
#  'father|husband|sister': 4.977450921497817e-06,
#  'father|husband|son': 3.600667800238372e-05,
#  'father|husband|uncle': 2.5560008571311188e-05,
#  'father|husband|wife': 5.6724126002610006e-06,
#  'father|mother|aunt': 2.426402260825956e-05,
#  'father|mother|brother': 3.1439066274678455e-05,
#  'father|mother|daughter': 0.00021007098374598368,
#  'father|mother|father': 5.53391821141892e-05,
#  'father|mother|husband': 0.0005598830319291162,
#  'father|mother|mother': 0.00010843225247340708,
#  'father|mother|nephew': 9.046253826049122e-05,
#  'father|mother|niece': 0.00015328158229182287,
#  'father|mother|sister': 8.362180753290413e-05,
#  'father|mother|son': 0.0008731404677501248,
#  'father|mother|uncle': 0.00022804150010626137,
#  'father|mother|wife': 1.4031479639456748e-06,
#  'father|nephew|aunt': 0.000169934325415706,
#  'father|nephew|brother': 7.264888146362701e-05,
#  'father|nephew|daughter': 2.9800152157962986e-05,
#  'father|nephew|father': 6.912961538438575e-05,
#  'father|nephew|husband': 1.1361836089607059e-06,
#  'father|nephew|mother': 0.0001265009305898672,
#  'father|nephew|nephew': 0.00010714938589212347,
#  'father|nephew|niece': 0.00011867073056025361,
#  'father|nephew|sister': 7.475242417995646e-05,
#  'father|nephew|son': 4.250554700445964e-05,
#  'father|nephew|uncle': 0.0005962913017992464,
#  'father|nephew|wife': 5.405260317075816e-05,
#  'father|niece|aunt': 0.0008018040747459302,
#  'father|niece|brother': 0.00027318974166342053,
#  'father|niece|daughter': 0.00021196243529675768,
#  'father|niece|father': 0.0001046823242166576,
#  'father|niece|husband': 4.604374057290417e-05,
#  'father|niece|mother': 0.000380145029952178,
#  'father|niece|nephew': 0.0004990786950887874,
#  'father|niece|niece': 0.0006551050003550385,
#  'father|niece|sister': 0.0002876986255879408,
#  'father|niece|son': 0.0001189579164225391,
#  'father|niece|uncle': 0.0022384590452255715,
#  'father|niece|wife': 2.1259638740864415e-06,
#  'father|sister|aunt': 1.1669989334157452e-05,
#  'father|sister|brother': 1.9096991829590376e-05,
#  'father|sister|daughter': 3.351660059995135e-05,
#  'father|sister|father': 7.497722468834585e-06,
#  'father|sister|husband': 4.687509782617949e-05,
#  'father|sister|mother': 2.0236628101914095e-05,
#  'father|sister|nephew': 8.02526644563678e-05,
#  'father|sister|niece': 0.000140048050478699,
#  'father|sister|sister': 0.00017205854033688905,
#  'father|sister|son': 4.6281189034158565e-05,
#  'father|sister|uncle': 0.00025056577500535504,
#  'father|sister|wife': 9.758784948489065e-07,
#  'father|son|aunt': 0.0034591691345788505,
#  'father|son|brother': 0.002273117544167313,
#  'father|son|daughter': 0.00047443997084092393,
#  'father|son|father': 0.0005730410222496105,
#  'father|son|husband': 1.7155762989248206e-05,
#  'father|son|mother': 0.0008382639833331521,
#  'father|son|nephew': 0.005320985494519647,
#  'father|son|niece': 0.0020166156992216613,
#  'father|son|sister': 0.001967989295761733,
#  'father|son|son': 0.0024315462859306187,
#  'father|son|uncle': 0.0037019894779505287,
#  'father|son|wife': 0.0005063897108757477,
#  'father|uncle|aunt': 0.0027285215287609077,
#  'father|uncle|brother': 0.0037272848358323634,
#  'father|uncle|daughter': 0.0007570411535630834,
#  'father|uncle|father': 0.0012969925456855305,
#  'father|uncle|husband': 3.8864180090638724e-05,
#  'father|uncle|mother': 0.0010288801622573653,
#  'father|uncle|nephew': 0.007939252165795274,
#  'father|uncle|niece': 0.0053225914058458255,
#  'father|uncle|sister': 0.002593576496388324,
#  'father|uncle|son': 0.0011838173728153656,
#  'father|uncle|uncle': 0.003103171784275919,
#  'father|uncle|wife': 0.0005452893969396891,
#  'father|wife|aunt': 0.00022507583373495194,
#  'father|wife|brother': 0.00024182314805195707,
#  'father|wife|daughter': 0.002986921848278016,
#  'father|wife|father': 0.00043285542441418945,
#  'father|wife|husband': 0.0001383865704002868,
#  'father|wife|mother': 0.0008285216802963087,
#  'father|wife|nephew': 0.0009901075243387198,
#  'father|wife|niece': 0.0005298582048946232,
#  'father|wife|sister': 0.0006032114108791193,
#  'father|wife|son': 0.0027788755033943215,
#  'father|wife|uncle': 0.000676282695121655,
#  'father|wife|wife': 7.835237530113361e-06,
#  'husband|aunt|aunt': 7.3483453671500734e-06,
#  'husband|aunt|brother': 1.8206912677196038e-05,
#  'husband|aunt|daughter': 3.269179961167539e-05,
#  'husband|aunt|father': 7.757422077523486e-06,
#  'husband|aunt|husband': 1.6154900982130477e-05,
#  'husband|aunt|mother': 1.9532874546405257e-05,
#  'husband|aunt|nephew': 8.545659090178116e-05,
#  'husband|aunt|niece': 0.0003676872061278193,
#  'husband|aunt|sister': 5.696495139352608e-05,
#  'husband|aunt|son': 3.387284205019133e-05,
#  'husband|aunt|uncle': 0.0004723435316226348,
#  'husband|aunt|wife': 1.1533716003013455e-07,
#  'husband|brother|aunt': 1.1807688638151384e-05,
#  'husband|brother|brother': 1.584534864744353e-05,
#  'husband|brother|daughter': 1.9074244523484503e-05,
#  'husband|brother|father': 1.272668125868569e-05,
#  'husband|brother|husband': 5.322933541298952e-08,
#  'husband|brother|mother': 1.7885080154923676e-05,
#  'husband|brother|nephew': 6.0695666691402965e-05,
#  'husband|brother|niece': 0.00044814315815293787,
#  'husband|brother|sister': 3.432076579247198e-05,
#  'husband|brother|son': 6.133944517801304e-05,
#  'husband|brother|uncle': 0.0009841317813596613,
#  'husband|brother|wife': 0.00015327146579627765,
#  'husband|daughter|aunt': 0.0006441299530001164,
#  'husband|daughter|brother': 0.0002491484581881147,
#  'husband|daughter|daughter': 0.00013693155419906033,
#  'husband|daughter|father': 6.075873562369262e-05,
#  'husband|daughter|husband': 0.00021914496879552509,
#  'husband|daughter|mother': 0.0001573379547164406,
#  'husband|daughter|nephew': 0.0003700999962571542,
#  'husband|daughter|niece': 0.0011547093272971745,
#  'husband|daughter|sister': 0.0002915653886046004,
#  'husband|daughter|son': 0.0011663706150863242,
#  'husband|daughter|uncle': 0.0047962284150577785,
#  'husband|daughter|wife': 6.340510164974796e-06,
#  'husband|father|aunt': 3.077744810334644e-05,
#  'husband|father|brother': 5.251750096988266e-05,
#  'husband|father|daughter': 0.00032950195174907593,
#  'husband|father|father': 0.00014728607539274755,
#  'husband|father|husband': 6.489131166912747e-07,
#  'husband|father|mother': 0.00017736077026286068,
#  'husband|father|nephew': 0.00024480121264512883,
#  'husband|father|niece': 0.0005079378194127158,
#  'husband|father|sister': 7.864994788634935e-05,
#  'husband|father|son': 0.0011811797270268412,
#  'husband|father|uncle': 0.001193309795516545,
#  'husband|father|wife': 0.0004056689948468255,
#  'husband|husband|aunt': 1.1140061823860362e-07,
#  'husband|husband|brother': 3.12644654907569e-07,
#  'husband|husband|daughter': 5.877055741791335e-07,
#  'husband|husband|father': 2.3922454669950783e-07,
#  'husband|husband|husband': 2.1846205072069866e-10,
#  'husband|husband|mother': 1.093269093509368e-07,
#  'husband|husband|nephew': 1.8586885354242722e-07,
#  'husband|husband|niece': 1.4198621249548573e-06,
#  'husband|husband|sister': 7.515401167459836e-08,
#  'husband|husband|son': 1.779719349537332e-06,
#  'husband|husband|uncle': 1.5319777787269632e-06,
#  'husband|husband|wife': 4.93003872301e-07,
#  'husband|mother|aunt': 4.836251793329311e-06,
#  'husband|mother|brother': 1.4124510963761225e-05,
#  'husband|mother|daughter': 8.974932874570607e-05,
#  'husband|mother|father': 1.8835065149266944e-05,
#  'husband|mother|husband': 0.0002000306929786262,
#  'husband|mother|mother': 3.1685881765852506e-05,
#  'husband|mother|nephew': 5.182027140521646e-05,
#  'husband|mother|niece': 0.00015426498209414907,
#  'husband|mother|sister': 2.768242430364077e-05,
#  'husband|mother|son': 0.0007312750048317865,
#  'husband|mother|uncle': 0.0003941838301589432,
#  'husband|mother|wife': 5.544303503209123e-07,
#  'husband|nephew|aunt': 7.441942228687132e-05,
#  'husband|nephew|brother': 8.223020062867366e-05,
#  'husband|nephew|daughter': 1.302933230638963e-05,
#  'husband|nephew|father': 4.128248496509945e-05,
#  'husband|nephew|husband': 7.614425142661489e-08,
#  'husband|nephew|mother': 6.479621833251994e-05,
#  'husband|nephew|nephew': 8.468948320785688e-05,
#  'husband|nephew|niece': 0.00021082612827054423,
#  'husband|nephew|sister': 4.5282377644180465e-05,
#  'husband|nephew|son': 6.511450273192128e-05,
#  'husband|nephew|uncle': 0.001006621881680288,
#  'husband|nephew|wife': 8.879343600403979e-05,
#  'husband|niece|aunt': 0.0007643813632059644,
#  'husband|niece|brother': 0.0008333977234730311,
#  'husband|niece|daughter': 0.00028094586285509293,
#  'husband|niece|father': 0.00017348218214776587,
#  'husband|niece|husband': 7.45161170091693e-05,
#  'husband|niece|mother': 0.00043156831072139557,
#  'husband|niece|nephew': 0.0008807646783533749,
#  'husband|niece|niece': 0.0026302424574816867,
#  'husband|niece|sister': 0.000334100344263818,
#  'husband|niece|son': 0.0004472566557823382,
#  'husband|niece|uncle': 0.00788698657805568,
#  'husband|niece|wife': 6.027496596312711e-06,
#  'husband|sister|aunt': 1.6425831035195987e-05,
#  'husband|sister|brother': 4.269738067929895e-05,
#  'husband|sister|daughter': 2.0238375464622323e-05,
#  'husband|sister|father': 1.0737662574106214e-05,
#  'husband|sister|husband': 1.0958648145438654e-05,
#  'husband|sister|mother': 2.8669970938694e-05,
#  'husband|sister|nephew': 0.00010117416469072188,
#  'husband|sister|niece': 0.0001954054850099469,
#  'husband|sister|sister': 8.758550874500327e-05,
#  'husband|sister|son': 6.692139207124224e-05,
#  'husband|sister|uncle': 0.0003920600912473334,
#  'husband|sister|wife': 2.525558530527151e-07,
#  'husband|son|aunt': 0.0018600192515068799,
#  'husband|son|brother': 0.0009724245962426196,
#  'husband|son|daughter': 0.0001452984742758336,
#  'husband|son|father': 0.00033639467408891344,
#  'husband|son|husband': 1.3135933990390002e-06,
#  'husband|son|mother': 8.094478316636455e-05,
#  'husband|son|nephew': 0.0006985333275507284,
#  'husband|son|niece': 0.00243503276772028,
#  'husband|son|sister': 0.0002405604291289461,
#  'husband|son|son': 0.003962373953849685,
#  'husband|son|uncle': 0.007663263232200456,
#  'husband|son|wife': 0.0015112444225725181,
#  'husband|uncle|aunt': 0.0006079046503300599,
#  'husband|uncle|brother': 0.002023308546699474,
#  'husband|uncle|daughter': 0.00026428703913151475,
#  'husband|uncle|father': 0.0003368543009708407,
#  'husband|uncle|husband': 6.973664290425643e-07,
#  'husband|uncle|mother': 0.00022439825481949716,
#  'husband|uncle|nephew': 0.005519575574448117,
#  'husband|uncle|niece': 0.00454809156947448,
#  'husband|uncle|sister': 0.0011527713667519404,
#  'husband|uncle|son': 0.0007790343110916133,
#  'husband|uncle|uncle': 0.0024143418459136585,
#  'husband|uncle|wife': 0.00048420725960419725,
#  'husband|wife|aunt': 0.00012102360746252087,
#  'husband|wife|brother': 0.0003417230679932659,
#  'husband|wife|daughter': 0.0010583711393085393,
#  'husband|wife|father': 0.0007387629704604243,
#  'husband|wife|husband': 3.211922968746799e-05,
#  'husband|wife|mother': 0.0004319202623059015,
#  'husband|wife|nephew': 0.0007763670327805144,
#  'husband|wife|niece': 0.0008839237635534236,
#  'husband|wife|sister': 0.00022654318907387727,
#  'husband|wife|son': 0.0031743865515476144,
#  'husband|wife|uncle': 0.0014940945818308626,
#  'husband|wife|wife': 3.154476210448032e-05,
#  'mother|aunt|aunt': 3.672209954289822e-06,
#  'mother|aunt|brother': 3.5811271664250733e-06,
#  'mother|aunt|daughter': 3.5817610028278705e-06,
#  'mother|aunt|father': 1.9291052004900442e-06,
#  'mother|aunt|husband': 6.957521960269746e-06,
#  'mother|aunt|mother': 4.3381695015839365e-06,
#  'mother|aunt|nephew': 3.334993149397289e-05,
#  'mother|aunt|niece': 5.698016848293755e-05,
#  'mother|aunt|sister': 3.643034017564552e-05,
#  'mother|aunt|son': 7.95801328911099e-06,
#  'mother|aunt|uncle': 0.00015496392396999702,
#  'mother|aunt|wife': 3.212798219338667e-08,
#  'mother|brother|aunt': 1.103310066896115e-06,
#  'mother|brother|brother': 2.9465023582451533e-06,
#  'mother|brother|daughter': 3.4669098589971015e-06,
#  'mother|brother|father': 1.5813977824238727e-06,
#  'mother|brother|husband': 3.211069093309626e-08,
#  'mother|brother|mother': 5.999044348338825e-06,
#  'mother|brother|nephew': 1.9427875389407476e-05,
#  'mother|brother|niece': 7.325654697749873e-05,
#  'mother|brother|sister': 2.4090872585464003e-05,
#  'mother|brother|son': 6.916531483379699e-06,
#  'mother|brother|uncle': 0.00011567956204850197,
#  'mother|brother|wife': 8.440190681119515e-06,
#  'mother|daughter|aunt': 5.457003113473573e-05,
#  'mother|daughter|brother': 2.041482553228691e-05,
#  'mother|daughter|daughter': 1.3505407377314418e-05,
#  'mother|daughter|father': 7.782089421830198e-06,
#  'mother|daughter|husband': 5.3691477344788505e-05,
#  'mother|daughter|mother': 3.449831998715656e-05,
#  'mother|daughter|nephew': 7.589967127182018e-05,
#  'mother|daughter|niece': 0.00011716839088339592,
#  'mother|daughter|sister': 6.936125553898796e-05,
#  'mother|daughter|son': 0.00010067795317849314,
#  'mother|daughter|uncle': 0.0012276337657500802,
#  'mother|daughter|wife': 2.8847673101436e-07,
#  'mother|father|aunt': 1.8464266026444225e-05,
#  'mother|father|brother': 2.13662665621593e-05,
#  'mother|father|daughter': 4.724805366387516e-05,
#  'mother|father|father': 5.119848938696843e-05,
#  'mother|father|husband': 2.538175710891899e-06,
#  'mother|father|mother': 3.096019960642833e-05,
#  'mother|father|nephew': 9.442294275932282e-05,
#  'mother|father|niece': 8.227680701362525e-05,
#  'mother|father|sister': 4.4053300432189455e-05,
#  'mother|father|son': 0.00010463475816592863,
#  'mother|father|uncle': 0.00017173355037395388,
#  'mother|father|wife': 8.770866317931586e-05,
#  'mother|husband|aunt': 0.0005670265236266495,
#  'mother|husband|brother': 0.0009321429731055467,
#  'mother|husband|daughter': 0.0016090660296513848,
#  'mother|husband|father': 0.000829037472622381,
#  'mother|husband|husband': 1.1670223963672921e-05,
#  'mother|husband|mother': 0.000672878602339851,
#  'mother|husband|nephew': 0.0013416256743416695,
#  'mother|husband|niece': 0.0019028207014789207,
#  'mother|husband|sister': 0.0005876707005967688,
#  'mother|husband|son': 0.0035366440947019275,
#  'mother|husband|uncle': 0.0020054559455558634,
#  'mother|husband|wife': 0.0012018298699754495,
#  'mother|mother|aunt': 1.2402535675718092e-05,
#  'mother|mother|brother': 1.0554079790354304e-05,
#  'mother|mother|daughter': 2.3128798524655117e-05,
#  'mother|mother|father': 1.8566995911654602e-05,
#  'mother|mother|husband': 0.00035044376578434455,
#  'mother|mother|mother': 2.933665106096949e-05,
#  'mother|mother|nephew': 5.281016691441667e-05,
#  'mother|mother|niece': 5.807264711340382e-05,
#  'mother|mother|sister': 2.8254129544358873e-05,
#  'mother|mother|son': 0.00036844229346659485,
#  'mother|mother|uncle': 0.0001633489514894712,
#  'mother|mother|wife': 3.5087652085360153e-07,
#  'mother|nephew|aunt': 9.042348899060934e-05,
#  'mother|nephew|brother': 5.6031224196801816e-05,
#  'mother|nephew|daughter': 1.9092100284360165e-05,
#  'mother|nephew|father': 6.152787501243275e-05,
#  'mother|nephew|husband': 7.502254205466587e-07,
#  'mother|nephew|mother': 8.982811894008301e-05,
#  'mother|nephew|nephew': 0.0001188251829750975,
#  'mother|nephew|niece': 0.0001586220660208757,
#  'mother|nephew|sister': 0.00010961668970923287,
#  'mother|nephew|son': 5.8761110733200145e-05,
#  'mother|nephew|uncle': 0.0011513027936666067,
#  'mother|nephew|wife': 8.205073501464653e-05,
#  'mother|niece|aunt': 0.0003280820884474927,
#  'mother|niece|brother': 0.00017543120919252112,
#  'mother|niece|daughter': 6.167063109579403e-05,
#  'mother|niece|father': 5.6389277293747424e-05,
#  'mother|niece|husband': 3.64782653434617e-05,
#  'mother|niece|mother': 0.00014914283947235066,
#  'mother|niece|nephew': 0.00035689890944617475,
#  'mother|niece|niece': 0.0005698576920789427,
#  'mother|niece|sister': 0.00016815276576059393,
#  'mother|niece|son': 0.0001120910488021665,
#  'mother|niece|uncle': 0.002854047866087487,
#  'mother|niece|wife': 5.968802764920676e-07,
#  'mother|sister|aunt': 4.7601932926139235e-05,
#  'mother|sister|brother': 6.818476635501654e-05,
#  'mother|sister|daughter': 3.783453940764287e-05,
#  'mother|sister|father': 1.4611905735404449e-05,
#  'mother|sister|husband': 0.00013821320238365135,
#  'mother|sister|mother': 3.4387669465688046e-05,
#  'mother|sister|nephew': 0.00028015322111851987,
#  'mother|sister|niece': 0.0003069474208047424,
#  'mother|sister|sister': 0.00044632724522779505,
#  'mother|sister|son': 0.00013145089369747708,
#  'mother|sister|uncle': 0.0007780349832481602,
#  'mother|sister|wife': 9.452700871693909e-08,
#  'mother|son|aunt': 0.0022301974012359227,
#  'mother|son|brother': 0.0023808697191842754,
#  'mother|son|daughter': 0.0010400876425170763,
#  'mother|son|father': 0.0008019518276923265,
#  'mother|son|husband': 1.4729782820062463e-05,
#  'mother|son|mother': 0.00037345504621206366,
#  'mother|son|nephew': 0.005956502664070662,
#  'mother|son|niece': 0.0043186489280566676,
#  'mother|son|sister': 0.0018495583155574702,
#  'mother|son|son': 0.0033931982648544023,
#  'nephew|niece|uncle': 0.003705456937346844,
#  'nephew|niece|wife': 5.242247919099233e-06,
#  'nephew|sister|aunt': 0.0003787017389227006,
#  'nephew|sister|brother': 0.00025588547460798797,
#  'nephew|sister|daughter': 9.814127216526292e-06,
#  'nephew|sister|father': 0.0001386467446473875,
#  'nephew|sister|husband': 1.8566143096479786e-05,
#  'nephew|sister|mother': 5.364963170436699e-05,
#  'nephew|sister|nephew': 0.0003499957654569258,
#  'nephew|sister|niece': 0.00030759150030822136,
#  'nephew|sister|sister': 0.0002444594704091781,
#  'nephew|sister|son': 5.0559352942235986e-05,
#  'nephew|sister|uncle': 0.00044268412738540186,
#  'nephew|sister|wife': 1.5266542201542541e-06,
#  'nephew|son|aunt': 0.0006158827836753218,
#  'nephew|son|brother': 0.00025320638753961267,
#  'nephew|son|daughter': 3.132603694486954e-05,
#  'nephew|son|father': 8.90584464664131e-05,
#  'nephew|son|husband': 1.8651330138317479e-07,
#  'nephew|son|mother': 4.173355797328313e-05,
#  'nephew|son|nephew': 0.00015777234317662645,
#  'nephew|son|niece': 0.00026698061587296834,
#  'nephew|son|sister': 6.072564566195204e-05,
#  'nephew|son|son': 0.00015481513434282415,
#  'nephew|son|uncle': 0.0007500465448560348,
#  'nephew|son|wife': 0.00015393860021589478,
#  'nephew|uncle|aunt': 0.00403612852885297,
#  'nephew|uncle|brother': 0.004775728629271188,
#  'nephew|uncle|daughter': 0.0009779964659843246,
#  'nephew|uncle|father': 0.0009402860897019434,
#  'nephew|uncle|husband': 6.321851881843527e-06,
#  'nephew|uncle|mother': 0.0008033160956402718,
#  'nephew|uncle|nephew': 0.010960197692079602,
#  'nephew|uncle|niece': 0.01375798314628825,
#  'nephew|uncle|sister': 0.0036590000113297565,
#  'nephew|uncle|son': 0.0011946757849001788,
#  'nephew|uncle|uncle': 0.006160201205828534,
#  'nephew|uncle|wife': 0.0008806234074340558,
#  'nephew|wife|aunt': 0.0003343387037696941,
#  'nephew|wife|brother': 0.00026772725252136953,
#  'nephew|wife|daughter': 0.00012361673023410696,
#  'nephew|wife|father': 0.0008316126569678598,
#  ...}

# %%
Ans = Query_B(body2head, ['mother', 'father'])
for i in range(3):
    print(Ans[i])
# Out:
# ('None', 0.9964069724082947)
# ('uncle', 0.0033464611042290926)
# ('father', 0.00021200094488449395)

# %%
def Query_H(body2head, query_head):
    """
    Answering Question: 
        Given head, what is the most predictive body?
    """
    for k, v in body2head.items():
        return head
# Out:
#   File "<ipython-input-19-6939bd9262e8>", line 7
#     return head
#          ^
# IndentationError: expected an indented block

# %%
N = 0
for rule in train_rule:
    body, head = rule.split('-')
    body_path = body.split('|')
    if body_path[0:2] == ['wife', 'mother'] and len(body_path) == 2:
        print(rule)
        N += 1
print(N)
# Out:
# wife|mother-None
# wife|mother-None
# wife|mother-None
# wife|mother-None
# wife|mother-aunt
# wife|mother-None
# 6

# %%
# Out:
# ['brother|wife|sister|niece-niece',
#  'brother|wife|sister|niece-niece',
#  'brother|wife|daughter-niece',
#  'brother|wife|daughter-niece',
#  'brother|uncle|uncle|nephew-uncle',
#  'brother|uncle|nephew-brother',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|sister-sister',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|nephew-son',
#  'brother|uncle|nephew|nephew-son',
#  'brother|uncle|nephew|father-father',
#  'brother|uncle|nephew|aunt-aunt',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|father-uncle',
#  'brother|uncle|nephew-brother',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|nephew-son',
#  'brother|uncle|nephew|brother-brother',
#  'brother|uncle|brother-uncle',
#  'brother|uncle|aunt|niece-mother',
#  'brother|uncle|aunt|nephew-uncle',
#  'brother|uncle|aunt|niece-mother',
#  'brother|uncle|aunt|nephew-uncle',
#  'brother|uncle-uncle',
#  'brother|sister-sister',
#  'brother|niece-niece',
#  'brother|nephew-son',
#  'brother|nephew-son',
#  'brother|nephew-nephew',
#  'brother|nephew|uncle-brother',
#  'brother|nephew|uncle|niece-niece',
#  'brother|nephew|sister-niece',
#  'brother|nephew|nephew|aunt-niece',
#  'brother|nephew|nephew|mother-niece',
#  'brother|nephew|aunt|niece-niece',
#  'brother|mother-mother',
#  'brother|daughter-niece',
#  'brother|brother-brother',
#  'brother|aunt-aunt',
#  'sister|sister-sister',
#  'sister|sister|sister|sister-sister',
#  'sister|sister|sister|father-father',
#  'sister|sister|sister|aunt-aunt',
#  'sister|sister|father-father',
#  'sister|sister|brother|sister-sister',
#  'sister|sister|brother|father-father',
#  'sister|sister|brother|aunt-aunt',
#  'sister|sister|brother|aunt-aunt',
#  'sister|sister|brother|sister-sister',
#  'sister|sister|brother|father-father',
#  'sister|sister|brother|aunt-aunt',
#  'sister|sister|aunt-aunt',
#  'sister|sister|aunt-aunt',
#  'sister|sister-sister',
#  'sister|aunt-aunt',
#  'sister|aunt-aunt',
#  'sister|uncle-uncle',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|father-uncle',
#  'sister|uncle|niece-sister',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|father-uncle',
#  'sister|uncle|nephew|uncle-uncle',
#  'sister|uncle|nephew|niece-niece',
#  'sister|uncle|nephew|niece-niece',
#  'sister|uncle|nephew|uncle-uncle',
#  'sister|uncle|nephew|uncle-uncle',
#  'sister|uncle|nephew|sister-sister',
#  'sister|uncle|nephew|niece-niece',
#  'sister|uncle|nephew|niece-niece',
#  'sister|uncle|nephew|nephew-nephew',
#  'sister|uncle|nephew|aunt-aunt',
#  'sister|uncle|father|daughter-aunt',
#  'sister|uncle|brother-uncle',
#  'sister|uncle|brother-uncle',
#  'sister|uncle-uncle',
#  'sister|sister-sister',
#  'sister|niece-niece',
#  'sister|husband|son-nephew',
#  'sister|husband|daughter-niece',
#  'sister|husband|daughter|aunt-sister',
#  'sister|husband|daughter-niece',
#  'sister|aunt-aunt',
#  'sister|aunt-aunt',
#  'sister|aunt|uncle|nephew-uncle',
#  'sister|aunt|son|uncle-uncle',
#  'sister|aunt|son|aunt-aunt',
#  'sister|aunt|son|aunt-aunt',
#  'sister|aunt|sister-aunt',
#  'sister|aunt|niece|uncle-uncle',
#  'sister|aunt|niece|aunt-aunt',
#  'sister|aunt|niece|aunt-aunt',
#  'sister|aunt|niece|aunt-aunt',
#  'sister|aunt|niece-sister',
#  'sister|aunt|niece|aunt-aunt',
#  'sister|aunt|niece|uncle-uncle',
#  'sister|aunt|niece|aunt-aunt',
#  'sister|aunt|niece|mother-aunt',
#  'sister|aunt|nephew|uncle-uncle',
#  'sister|aunt|nephew|aunt-aunt',
#  'sister|aunt|nephew|uncle-uncle',
#  'sister|aunt|nephew|aunt-aunt',
#  'sister|aunt|nephew|uncle-uncle',
#  'sister|aunt|nephew|aunt-aunt',
#  'sister|aunt|mother|daughter-aunt',
#  'sister|aunt|brother-uncle',
#  'sister|sister|niece-niece',
#  'sister|sister|niece|uncle-brother',
#  'sister|sister|niece|sister-niece',
#  'sister|sister|niece|mother-sister',
#  'sister|sister|niece|brother-nephew',
#  'sister|sister|niece|brother-nephew',
#  'sister|sister|niece-niece',
#  'sister|sister|niece|aunt-sister',
#  'sister|sister|nephew-nephew',
#  'sister|sister|mother|husband-father',
#  'sister|sister|brother-brother',
#  'sister|sister-sister',
#  'sister|niece-niece',
#  'sister|nephew-nephew',
#  'sister|nephew-nephew',
#  'sister|father-father',
#  'mother|uncle|niece|sister-aunt',
#  'mother|uncle|niece|niece-sister',
#  'mother|uncle|niece|niece-wife',
#  'mother|uncle|niece|brother-uncle',
#  'mother|uncle|niece|brother-uncle',
#  'mother|uncle|niece|brother-uncle',
#  'mother|uncle|niece-aunt',
#  'mother|uncle|nephew-uncle',
#  'mother|son-brother',
#  'mother|son|wife|son-nephew',
#  'mother|son|wife|son-nephew',
#  'mother|son|uncle-uncle',
#  'mother|son|uncle-uncle',
#  'mother|son|uncle-uncle',
#  'mother|son|uncle|sister-aunt',
#  'mother|son|uncle|brother-father',
#  'mother|son|son-nephew',
#  'mother|son|son-nephew',
#  'mother|son|sister-sister',
#  'mother|son|niece-daughter',
#  'mother|son|niece|sister-daughter',
#  'mother|son|niece|brother-son',
#  'mother|son|niece|aunt-sister',
#  'mother|son|niece-daughter',
#  'mother|son|nephew-son',
#  'mother|son|nephew-son',
#  'mother|son|father-father',
#  'mother|son|daughter-niece',
#  'mother|son|daughter|brother-nephew',
#  'mother|son|daughter|brother-nephew',
#  'mother|son|aunt-aunt',
#  'mother|son|aunt-aunt',
#  'mother|sister-aunt',
#  'mother|niece-wife',
#  'mother|husband-father',
#  'mother|daughter-sister',
#  'mother|brother-uncle',
#  'mother|brother|sister-aunt',
#  'mother|brother|niece-wife',
#  'mother|brother|niece-sister',
#  'mother|brother|mother|son-uncle',
#  'mother|brother|mother|daughter-aunt',
#  'mother|brother|brother-uncle',
#  'mother|brother|brother-uncle',
#  'mother|brother|brother-uncle',
#  'mother|brother-uncle',
#  'mother|brother-uncle',
#  'sister|uncle-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-father',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-father',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|sister-aunt',
#  'sister|uncle|niece-sister',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|nephew-son',
#  'sister|uncle|niece|nephew-nephew',
#  'sister|uncle|niece|father-father',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|uncle-father',
#  'sister|uncle|niece|father-uncle',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|niece|uncle-father',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|nephew-brother',
#  'sister|uncle|nephew|uncle-uncle',
#  'sister|uncle|nephew|uncle-uncle',
#  'sister|uncle|nephew|sister-sister',
#  'sister|uncle|nephew|niece-daughter',
#  'sister|uncle|nephew|niece-niece',
#  'sister|uncle|nephew|nephew-son',
#  'sister|uncle|nephew|mother-mother',
#  'sister|uncle|nephew|daughter-niece',
#  'sister|uncle|mother|son-father',
#  'sister|uncle|brother-father',
#  'sister|uncle|brother-uncle',
#  'sister|sister-sister',
#  'sister|niece-daughter',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|mother-mother',
#  'sister|brother-brother',
#  'sister|aunt-aunt',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|father-father',
#  'sister|son|uncle|brother-brother',
#  'sister|son|uncle-brother',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|nephew-nephew',
#  'sister|son|uncle|brother-brother',
#  'sister|son|brother-nephew',
#  'sister|son-nephew',
#  'sister|brother-brother',
#  'sister|sister-sister',
#  'sister|sister|niece-daughter',
#  'sister|sister|niece|uncle-brother',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|aunt-sister',
#  'sister|sister|niece-daughter',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|aunt-sister',
#  'sister|sister|niece-daughter',
#  'sister|sister|niece-daughter',
#  'sister|sister|niece|uncle-brother',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|sister-daughter',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|brother-son',
#  'sister|sister|niece|aunt-sister',
#  'sister|sister|nephew-son',
#  'sister|sister|nephew-son',
#  'sister|sister|nephew-nephew',
#  'sister|sister|nephew|father-brother',
#  'sister|sister|nephew|brother-nephew',
#  'sister|sister|nephew|aunt-sister',
#  'sister|sister|mother|son-brother',
#  'sister|sister|mother|daughter-sister',
#  'sister|niece-daughter',
#  'sister|niece-daughter',
#  'sister|nephew-son',
#  'sister|nephew-nephew',
#  'sister|nephew-nephew',
#  'sister|nephew-son',
#  'sister|brother-brother',
#  'niece|uncle|son-nephew',
#  'niece|uncle|son|uncle-brother',
#  'niece|uncle|son|aunt-sister',
#  'niece|uncle|son|aunt-sister',
#  'niece|uncle|sister-sister',
#  'niece|uncle|sister-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|father-brother',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|mother-sister',
#  'niece|uncle|niece|husband-nephew',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|mother-sister',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|mother-sister',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|sister-niece',
#  'niece|uncle|nephew|sister-niece',
#  'niece|uncle|nephew|brother-nephew',
#  'niece|uncle|nephew|brother-nephew',
#  'niece|uncle|nephew|aunt-sister',
#  'niece|uncle|nephew|aunt-sister',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|mother-mother',
#  'niece|uncle|mother|son-brother',
#  'niece|uncle|mother|daughter-sister',
#  'niece|uncle|mother|daughter-sister',
#  'niece|uncle|daughter-niece',
#  'niece|uncle|daughter|uncle-brother',
#  'niece|uncle|daughter|uncle-brother',
#  'niece|uncle|daughter|brother-nephew',
#  'niece|uncle|daughter|aunt-sister',
#  'niece|uncle|daughter|aunt-sister',
#  'niece|uncle|brother-brother',
#  'niece|uncle-brother',
#  'niece|sister-niece',
#  'niece|aunt-sister',
#  'niece|uncle-brother',
#  'niece|uncle|uncle-uncle',
#  'niece|uncle|uncle|niece-sister',
#  'niece|uncle|uncle|nephew-brother',
#  'niece|uncle|uncle|nephew-brother',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle|niece-sister',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle-uncle',
#  'niece|uncle|son|uncle-brother',
#  'niece|uncle|son|sister-niece',
#  'niece|uncle|son|brother-nephew',
#  'niece|uncle|son|brother-nephew',
#  'niece|uncle|sister-sister',
#  'niece|uncle|sister-sister',
#  'niece|uncle|sister|uncle-uncle',
#  'niece|uncle|sister|uncle-uncle',
#  'niece|uncle|sister|uncle-uncle',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|nephew-nephew',
#  'niece|uncle|sister|nephew-nephew',
#  'niece|uncle|sister|nephew-nephew',
#  'niece|uncle|sister|nephew-nephew',
#  'niece|uncle|sister|brother-brother',
#  'niece|uncle|sister|brother-brother',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|aunt-sister',
#  'niece|uncle|daughter-niece',
#  'niece|uncle|brother-brother',
#  'niece|mother|son-nephew',
#  'niece|father-brother',
#  'brother|wife|nephew|uncle-husband',
#  'brother|wife|nephew|uncle-husband',
#  'brother|sister-sister',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew|father-brother',
#  'brother|sister|mother-mother',
#  'brother|sister|mother|husband-father',
#  'brother|sister|father-father',
#  'brother|father-father',
#  'uncle|sister-aunt',
#  'uncle|sister|sister-aunt',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|niece-sister',
#  'uncle|sister|sister|nephew-brother',
#  'uncle|sister|sister|nephew-brother',
#  'uncle|sister|sister|brother-uncle',
#  'uncle|sister|sister|brother-uncle',
#  'uncle|sister|sister|brother-uncle',
#  'uncle|sister|niece-sister',
#  'uncle|sister|niece|sister-sister',
#  'uncle|sister|niece|sister-sister',
#  'uncle|sister|niece|sister-sister',
#  'uncle|sister|niece|niece-niece',
#  'uncle|sister|niece|nephew-nephew',
#  'uncle|sister|niece|brother-brother',
#  'uncle|sister|niece|brother-brother',
#  'uncle|sister|niece|aunt-aunt',
#  'uncle|sister|niece-sister',
#  'uncle|sister|niece-sister',
#  'uncle|sister|nephew-brother',
#  'uncle|sister|nephew|uncle-uncle',
#  'uncle|sister|nephew|uncle-uncle',
#  'uncle|sister|nephew|uncle-uncle',
#  'uncle|sister|nephew|uncle-uncle',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|sister-sister',
#  'uncle|sister|nephew|nephew-nephew',
#  'uncle|sister|nephew|brother-brother',
#  'uncle|sister|nephew-brother',
#  'uncle|sister|brother-uncle',
#  'uncle|sister|brother-uncle',
#  'uncle|sister|brother-uncle',
#  'uncle|sister-aunt',
#  'uncle|niece-sister',
#  'uncle|niece-sister',
#  'uncle|niece-sister',
#  'uncle|niece-sister',
#  'uncle|niece-sister',
#  'uncle|nephew-brother',
#  'uncle|nephew-brother',
#  'uncle|nephew-brother',
#  'uncle|brother-uncle',
#  'uncle|brother-uncle',
#  'uncle|brother-uncle',
#  'nephew|mother-sister',
#  'nephew|mother|father-father',
#  'niece|uncle-brother',
#  'niece|uncle|wife|son-nephew',
#  'niece|uncle|wife|son-nephew',
#  'niece|uncle|uncle|sister-aunt',
#  'niece|uncle|uncle|sister-aunt',
#  'niece|uncle|uncle|sister-aunt',
#  'niece|uncle|uncle|nephew-brother',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle|brother-uncle',
#  'niece|uncle|uncle-uncle',
#  'niece|uncle|uncle-uncle',
#  'niece|uncle|son-nephew',
#  'niece|uncle|son-nephew',
#  'niece|uncle|son-nephew',
#  'niece|uncle|son|uncle-brother',
#  'niece|uncle|son|brother-nephew',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|niece|brother-nephew',
#  'niece|uncle|nephew-son',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|mother-wife',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|sister-niece',
#  'niece|uncle|nephew|brother-nephew',
#  'niece|uncle|nephew|brother-nephew',
#  'niece|uncle|nephew-son',
#  'niece|uncle|nephew|uncle-brother',
#  'niece|uncle|nephew|sister-daughter',
#  'niece|uncle|father|wife-mother',
#  'niece|uncle|father|son-brother',
#  'niece|uncle|father|sister-aunt',
#  'niece|uncle|father|brother-uncle',
#  'niece|uncle|brother-brother',
#  'niece|uncle|aunt-aunt',
#  'niece|uncle|aunt-aunt',
#  'niece|uncle|aunt-aunt',
#  'niece|uncle|aunt-aunt',
#  'niece|uncle-brother',
#  'niece|son|uncle|uncle-brother',
#  'niece|son|uncle|uncle-brother',
#  'niece|son|uncle|sister-niece',
#  'niece|sister-niece',
#  'sister|sister|uncle-uncle',
#  'sister|sister|uncle|sister-aunt',
#  'sister|sister|uncle|nephew-brother',
#  'sister|sister|sister-sister',
#  'sister|sister|sister|uncle-uncle',
#  'sister|sister|sister|nephew-nephew',
#  'sister|sister|sister|mother-mother',
#  'sister|sister|sister|brother-brother',
#  'sister|sister|nephew-nephew',
#  'sister|sister|nephew|father-brother',
#  'sister|sister|nephew|aunt-sister',
#  'sister|sister|nephew-nephew',
#  'sister|sister|nephew|father-brother',
#  'sister|sister|mother-mother',
#  'sister|sister|brother-brother',
#  'sister|sister|aunt-aunt',
#  'sister|nephew-nephew',
#  'sister|nephew-nephew',
#  'sister|mother-mother',
#  'sister|brother-brother',
#  'son|son|aunt-daughter',
#  'son|son|aunt|mother-wife',
#  'son|sister-daughter',
#  'son|mother-wife',
#  'mother|husband|son-brother',
#  'aunt|uncle|sister|nephew-uncle',
#  'aunt|uncle|sister|nephew-uncle',
#  'aunt|uncle|sister|nephew-uncle',
#  'aunt|uncle|niece-mother',
#  'aunt|uncle|niece|brother-uncle',
#  'aunt|uncle|niece|brother-uncle',
#  'aunt|uncle|niece-aunt',
#  'aunt|uncle|niece|brother-uncle',
#  'aunt|uncle|nephew-uncle',
#  'aunt|uncle|nephew-uncle',
#  'aunt|uncle|nephew-uncle',
#  'aunt|sister-mother',
#  'aunt|brother-uncle',
#  'aunt|brother-uncle',
#  'aunt|brother-uncle',
#  'uncle|wife|daughter|aunt-aunt',
#  'uncle|wife|daughter|aunt-aunt',
#  'uncle|wife|daughter|aunt-aunt',
#  'uncle|sister-aunt',
#  'uncle|sister-aunt',
#  'uncle|niece|uncle-father',
#  'uncle|niece|uncle|sister-aunt',
#  'uncle|niece|uncle|niece-wife',
#  'uncle|niece|mother-aunt',
#  'uncle|niece-wife',
#  'uncle|niece|uncle-father',
#  'uncle|niece|sister|sister-wife',
#  'uncle|niece|sister|niece-daughter',
#  'uncle|niece|sister|mother-aunt',
#  'uncle|niece|sister|aunt-aunt',
#  'uncle|niece|sister|aunt-aunt',
#  'uncle|niece|niece|aunt-wife',
#  'uncle|niece|mother-aunt',
#  'uncle|niece|aunt-aunt',
#  'nephew|uncle-brother',
#  'nephew|uncle|wife|son-nephew',
#  'nephew|uncle|wife|daughter-niece',
#  'nephew|uncle|son|uncle-brother',
#  'nephew|uncle|son|brother-nephew',
#  'nephew|uncle|son|brother-nephew',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son-nephew',
#  'nephew|uncle|son|uncle-brother',
#  'nephew|uncle|son|uncle-brother',
#  'nephew|uncle|son|brother-nephew',
#  'nephew|uncle|son|brother-nephew',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son|aunt-sister',
#  'nephew|uncle|son-nephew',
#  'nephew|uncle|sister-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|sister-daughter',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|mother-mother',
#  'nephew|uncle|mother|son-brother',
#  'nephew|uncle|mother|husband-father',
#  'nephew|uncle|mother|daughter-sister',
#  'nephew|uncle|mother|daughter-sister',
#  'nephew|uncle|father-father',
#  'nephew|uncle|daughter|uncle-brother',
#  'nephew|uncle|daughter|uncle-brother',
#  'nephew|uncle|daughter|sister-niece',
#  'nephew|uncle|daughter|brother-nephew',
#  'nephew|uncle|daughter|brother-nephew',
#  'nephew|uncle|daughter|aunt-sister',
#  'nephew|uncle|daughter|aunt-sister',
#  'nephew|uncle|daughter-niece',
#  'nephew|uncle|brother-brother',
#  'nephew|uncle|brother-brother',
#  'nephew|uncle-brother',
#  'nephew|uncle-brother',
#  'nephew|mother-sister',
#  'nephew|father|wife-sister',
#  'nephew|father|son-nephew',
#  'nephew|father|son|uncle-brother',
#  'nephew|father|son|mother-sister',
#  'nephew|daughter|uncle-nephew',
#  'nephew|aunt-sister',
#  'nephew|aunt-sister',
#  'brother|wife|son-nephew',
#  'brother|wife|son|uncle-brother',
#  'brother|son-nephew',
#  'brother|son|uncle-brother',
#  'brother|son|uncle|nephew-nephew',
#  'brother|son|uncle|mother-mother',
#  'brother|son|uncle|father-father',
#  'brother|son|uncle|brother-brother',
#  'brother|brother-brother',
#  'brother|sister-sister',
#  'brother|sister|niece-daughter',
#  'brother|sister|niece|sister-daughter',
#  'brother|sister|niece|brother-son',
#  'brother|sister|niece-daughter',
#  'brother|sister|aunt-aunt',
#  'brother|sister|aunt|brother-father',
#  'brother|sister|aunt-aunt',
#  'brother|sister|aunt|sister-aunt',
#  'brother|sister|aunt|brother-father',
#  'brother|niece-daughter',
#  'brother|nephew-son',
#  'brother|mother-mother',
#  'brother|mother|daughter-sister',
#  'brother|father-father',
#  'brother|uncle-uncle',
#  'brother|uncle|sister|sister-aunt',
#  'brother|uncle|sister|sister-aunt',
#  'brother|uncle|sister|nephew-brother',
#  'brother|uncle|sister|brother-father',
#  'brother|uncle|sister-aunt',
#  'brother|uncle|sister-aunt',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|aunt-aunt',
#  'brother|uncle|niece|aunt-aunt',
#  'brother|uncle|niece|aunt-aunt',
#  'brother|uncle|niece|uncle-father',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|aunt-aunt',
#  'brother|uncle|niece|aunt-aunt',
#  'brother|uncle|nephew-brother',
#  'brother|uncle|nephew-brother',
#  'brother|uncle|nephew|son-nephew',
#  'brother|uncle|nephew|son-nephew',
#  'brother|uncle|nephew|son-nephew',
#  'brother|uncle|nephew|son-nephew',
#  'brother|uncle|nephew|son-nephew',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|niece-niece',
#  'brother|uncle|nephew|mother-mother',
#  'brother|uncle|nephew|father-father',
#  'brother|uncle|nephew|daughter-niece',
#  'brother|uncle|nephew|daughter-niece',
#  'brother|uncle|nephew|daughter-niece',
#  'brother|uncle|nephew|brother-brother',
#  'brother|uncle|nephew|aunt-aunt',
#  'brother|uncle|nephew|aunt-aunt',
#  'brother|uncle|nephew|uncle-father',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|daughter-niece',
#  'brother|uncle|nephew|aunt-aunt',
#  'brother|uncle|brother-father',
#  'brother|uncle-uncle',
#  'brother|sister-sister',
#  'brother|sister|uncle-uncle',
#  'brother|sister|uncle-uncle',
#  'brother|sister|niece-niece',
#  'brother|sister|niece|uncle-brother',
#  'brother|sister|niece|uncle-brother',
#  'brother|sister|niece|sister-niece',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|niece|aunt-sister',
#  'brother|sister|niece-niece',
#  'brother|sister|niece-niece',
#  'brother|sister|niece-niece',
#  'brother|sister|niece|uncle-brother',
#  'brother|sister|niece|sister-niece',
#  'brother|sister|niece|sister-niece',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|niece|brother-nephew',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew-nephew',
#  'brother|sister|nephew|sister-niece',
#  'brother|sister|nephew|sister-niece',
#  'brother|sister|nephew|father-brother',
#  'brother|sister|nephew|brother-nephew',
#  'brother|sister|nephew|brother-nephew',
#  'brother|sister|nephew|brother-nephew',
#  'brother|sister|nephew|brother-nephew',
#  'brother|sister|nephew|aunt-sister',
#  'brother|sister|father-father',
#  'brother|sister|brother-brother',
#  'brother|sister|brother-brother',
#  'brother|sister|aunt-aunt',
#  'brother|sister-sister',
#  'brother|niece-niece',
#  'brother|niece-niece',
#  'brother|niece-niece',
#  'brother|niece-niece',
#  'brother|niece-niece',
#  'brother|niece|uncle-brother',
#  'brother|niece|uncle-brother',
#  'brother|niece|husband-nephew',
#  'brother|niece|aunt-sister',
#  'brother|niece|aunt-sister',
#  'brother|nephew-nephew',
#  'brother|nephew-nephew',
#  'brother|nephew|uncle-brother',
#  'brother|nephew|uncle-brother',
#  'brother|nephew|mother|daughter-niece',
#  'brother|nephew|father-brother',
#  'brother|nephew|aunt-sister',
#  'brother|nephew|aunt-sister',
#  'brother|nephew-nephew',
#  'brother|nephew-nephew',
#  'brother|nephew-nephew',
#  'brother|nephew-nephew',
#  'brother|nephew-nephew',
#  'brother|mother-mother',
#  'brother|father-father',
#  'brother|brother-brother',
#  'brother|brother-brother',
#  'brother|brother-brother',
#  'brother|aunt-aunt',
#  'brother|aunt-aunt',
#  'brother|aunt-aunt',
#  'mother|husband|son-brother',
#  'mother|husband|son|sister-sister',
#  'mother|husband|son|sister-sister',
#  'mother|husband|daughter-sister',
#  'mother|husband|daughter-sister',
#  'mother|daughter-sister',
#  'mother|daughter-sister',
#  'sister|uncle-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|sister-aunt',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|nephew-nephew',
#  'sister|uncle|niece|nephew-nephew',
#  'sister|uncle|niece|mother-mother',
#  'sister|uncle|niece|brother-brother',
#  'sister|uncle|niece|aunt-aunt',
#  'sister|uncle|brother-uncle',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|niece|father-brother',
#  'sister|niece|brother-nephew',
#  'sister|niece|brother|father-brother',
#  'sister|niece-niece',
#  'sister|niece-niece',
#  'sister|nephew-nephew',
#  'sister|nephew-nephew',
#  'sister|nephew-nephew',
#  'sister|nephew-son',
#  'sister|nephew|uncle-brother',
#  'sister|aunt-aunt',
#  'nephew|uncle-brother',
#  'nephew|uncle|uncle-uncle',
#  'nephew|uncle|uncle|sister-aunt',
#  'nephew|uncle|uncle|sister-aunt',
#  'nephew|uncle|uncle|nephew-brother',
#  'nephew|uncle|uncle|nephew-brother',
#  'nephew|uncle|uncle|brother-father',
#  'nephew|uncle|uncle|sister-aunt',
#  'nephew|uncle|uncle|sister-aunt',
#  'nephew|uncle|uncle|sister-aunt',
#  'nephew|uncle|uncle|niece-sister',
#  'nephew|uncle|uncle|niece-sister',
#  'nephew|uncle|uncle|nephew-brother',
#  'nephew|uncle|uncle|nephew-brother',
#  'nephew|uncle|uncle|nephew-brother',
#  'nephew|uncle|uncle|brother-father',
#  'nephew|uncle|uncle|brother-uncle',
#  'nephew|uncle|uncle|brother-uncle',
#  'nephew|uncle|sister-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|sister-niece',
#  'nephew|uncle|niece|sister-niece',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|sister-niece',
#  'nephew|uncle|niece|father-brother',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|brother-nephew',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|uncle-brother',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece|aunt-sister',
#  'nephew|uncle|niece-niece',
#  'nephew|uncle|nephew-nephew',
#  'nephew|uncle|nephew-nephew',
#  'nephew|uncle|nephew|uncle-brother',
#  'nephew|uncle|nephew|uncle-brother',
#  'nephew|uncle|nephew|sister-niece',
#  'nephew|uncle|nephew|sister-niece',
#  'nephew|uncle|nephew|sister-niece',
#  'nephew|uncle|nephew|sister-niece',
#  'nephew|uncle|nephew|father-brother',
#  'nephew|uncle|nephew|brother-nephew',
#  'nephew|uncle|nephew|brother-nephew',
#  'nephew|uncle|nephew|brother-nephew',
#  'nephew|uncle|nephew|brother-nephew',
#  'nephew|uncle|nephew|aunt-sister',
#  'nephew|uncle|nephew|aunt-sister',
#  'nephew|uncle|nephew-nephew',
#  'nephew|uncle|nephew-nephew',
#  'nephew|uncle|nephew-nephew',
#  'nephew|uncle|nephew|uncle-brother',
#  'nephew|uncle|nephew|uncle-brother',
#  'nephew|uncle|nephew|uncle-brother',
#  'nephew|uncle|nephew|sister-niece',
#  'nephew|uncle|nephew|aunt-sister',
#  'nephew|uncle|father-father',
#  'nephew|uncle|brother-brother',
#  'nephew|uncle|brother-brother',
#  'nephew|uncle|aunt-aunt',
#  'nephew|sister-niece',
#  'nephew|sister-niece',
#  'nephew|sister-niece',
#  'nephew|sister-niece',
#  'nephew|sister|uncle-brother',
#  'nephew|sister|uncle-brother',
#  'nephew|sister|uncle-brother',
#  'nephew|sister|sister-niece',
#  'nephew|sister|sister-niece',
#  'nephew|sister|sister-niece',
#  'nephew|sister|husband-nephew',
#  'nephew|sister|brother-nephew',
#  'nephew|sister|brother-nephew',
#  'nephew|sister|brother-nephew',
#  'nephew|sister|brother-nephew',
#  'nephew|sister|aunt-sister',
#  'nephew|brother-nephew',
#  'nephew|brother-nephew',
#  'nephew|brother-nephew',
#  'nephew|brother-nephew',
#  'nephew|aunt-sister',
#  'nephew|aunt-sister',
#  'niece|uncle-brother',
#  'niece|uncle|niece-daughter',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-daughter',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|sister-daughter',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|mother-mother',
#  'niece|uncle|mother|husband-father',
#  'niece|uncle|mother|daughter-sister',
#  'niece|uncle|brother-brother',
#  'niece|sister|uncle-brother',
#  'niece|sister|aunt-sister',
#  'niece|aunt-sister',
#  'niece|uncle-brother',
#  'niece|uncle|wife|son-nephew',
#  'niece|uncle|uncle-uncle',
#  'niece|uncle|uncle|niece-sister',
#  'niece|uncle|uncle|niece-sister',
#  'niece|uncle|uncle|nephew-brother',
#  'niece|uncle|uncle|nephew-brother',
#  'niece|uncle|son-nephew',
#  'niece|uncle|sister-sister',
#  'niece|uncle|sister|uncle-uncle',
#  'niece|uncle|sister|sister-sister',
#  'niece|uncle|sister|sister-sister',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|niece-niece',
#  'niece|uncle|sister|nephew-nephew',
#  'niece|uncle|sister|mother-mother',
#  'niece|uncle|sister|aunt-aunt',
#  'niece|uncle|sister-sister',
#  'niece|uncle|sister-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|sister-niece',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|uncle-brother',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece|aunt-sister',
#  'niece|uncle|niece-niece',
#  'niece|uncle|nephew-nephew',
#  'niece|uncle|brother-brother',
#  'niece|uncle|aunt-aunt',
#  'niece|uncle-brother',
#  'niece|niece|father-nephew',
#  'niece|niece|father|uncle-brother',
#  'niece|niece|father|uncle-brother',
#  'niece|niece|father|aunt-sister',
#  'niece|aunt-sister',
#  'niece|aunt-sister',
#  'niece|aunt-sister',
#  'brother|uncle-uncle',
#  'brother|uncle|uncle|niece-aunt',
#  'brother|uncle|uncle|nephew-uncle',
#  'brother|uncle|uncle|nephew-uncle',
#  'brother|uncle|uncle|nephew-uncle',
#  'brother|uncle|uncle|niece-aunt',
#  'brother|uncle|uncle|nephew-uncle',
#  'brother|uncle|son|uncle-uncle',
#  'brother|uncle|sister-aunt',
#  'brother|uncle|sister|brother-uncle',
#  'brother|uncle|sister|brother-uncle',
#  'brother|uncle|sister|brother-uncle',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece-sister',
#  'brother|uncle|niece|uncle-uncle',
#  'brother|uncle|niece|mother-mother',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|uncle-uncle',
#  'brother|uncle|nephew|aunt-aunt',
#  'brother|uncle|brother-uncle',
#  'brother|uncle|brother-uncle',
#  'brother|sister-sister',
#  'brother|mother-mother',
#  'brother|aunt-aunt',
#  'sister|uncle-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-father',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|niece-aunt',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|uncle|nephew-father',
#  'sister|uncle|uncle|nephew-uncle',
#  'sister|uncle|niece-sister',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|uncle-uncle',
#  'sister|uncle|niece|niece-niece',
#  'sister|uncle|niece|niece-daughter',
#  ...]
